# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 40px 20px 40px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h1 style="font-size: 32px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">Renewable Power Trends: 1965-2022</h1>
#     <h2 style="font-size: 24px; font-weight: bold; color: #8B0000; text-align: center; font-family: 'Times New Roman'; padding: 10px;">The Rise of Wind, Hydro, and Solar Electricity</h2>
# </div>

# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">🌍 Business Problem</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         With the increasing emphasis on sustainable development, the role of renewable energy sources such as wind, hydro, solar, and other renewables in global energy production has become more critical than ever. The journey from 1965 to 2022 reflects a significant transformation in the energy landscape. This dataset offers a comprehensive view of this shift, highlighting regional advancements and technological progress in renewable energy.
#     </p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li>📊 <strong>Comparative Regional Growth:</strong> Assess which countries or regions have significantly advanced in adopting renewable energy. Examine the growth patterns in wind, solar, hydro, and other renewable sources, highlighting leaders and emerging players in the renewable energy landscape.</li>
#         <li>🔍 <strong>Strategic Planning for Energy Transition:</strong> Utilize the data to inform policy decisions, investment strategies, and future projects, focusing on regions and technologies with the highest growth potential.</li>
#         <li>🌿 <strong>Eco-Friendly Development:</strong> Understand the environmental implications of shifting towards renewable sources. This analysis aids in strategizing for reduced carbon footprints and sustainable development.</li>
#     </ul>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         Analyzing this dataset provides valuable insights into historical trends and paves the way for informed decisions, guiding the path towards a cleaner and more responsible energy future.
#     </p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #FFA500; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #FFA500; font-family: 'Georgia'; padding: 10px;">📊 Dataset Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">The dataset contains a total of <strong>8851 observations</strong> and <strong>7 variables</strong>.</p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Indicates the region name. There are a total of <strong>251</strong> different regions.</li>
#         <li><strong>Code:</strong> Contains region codes. There are a total of <strong>217</strong> different codes.</li>
#         <li><strong>Year:</strong> Shows the analyzed year, ranging from <strong>1965</strong> to <strong>2022</strong>.</li>
#         <li><strong>Electricity from Wind (TWh):</strong> Represents wind energy generation. Values range from <strong>0.0</strong> to <strong>1848.26</strong> TWh.</li>
#         <li><strong>Electricity from Hydro (TWh):</strong> Represents hydroelectric energy generation. Values range from <strong>0.0</strong> to <strong>4340.61</strong> TWh.</li>
#         <li><strong>Electricity from Solar (TWh):</strong> Represents solar energy generation. Values range from <strong>0.0</strong> to <strong>1040.5</strong> TWh.</li>
#         <li><strong>Other Renewables (TWh):</strong> Includes bioenergy and other renewable energy sources. Values range from <strong>0.0</strong> to <strong>761.93005</strong> TWh.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#Total-Renewable-Energy-Production-Over-the-Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;"> Total Renewable Energy Production Over the Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#TotalRenewableEnergyProductionbySourceOvertheYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Total Renewable Energy Production by Source Over the Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#MostUsedRenewableEnergySourcebyCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Most Used Renewable Energy Source by Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#RankingofTopProducingCountriesforEachEnergySource" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Ranking of Top Producing Countries for Each Energy Source</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#AnnualGrowthRatesinRenewableEnergyUse" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Annual Growth Rates in Renewable Energy Use</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#RegionalRenewableEnergyProduction" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Regional Renewable Energy Production</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#RenewableEnergyTrendsinDevelopingCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Trends in Developing Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#RenewableEnergyTrendsinDevelopedCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Trends in Developed Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#RelationshipBetweenRenewableEnergySources" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Relationship Between Renewable Energy Sources</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#TurkeysElectricityGenerationbyEnergySourcesin2000-2022" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Turkey's Electricity Generation by Energy Sources in 2000-2022</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#DistributionofRenewableEnergySourcesinTurkeysElectricityGenerationbetween2018-2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Distribution of Renewable Energy Sources in Turkey's Electricity Generation between 2018-2021</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#ComparisonofTurkeysElectricityGenerationinEuropein2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Comparison of Turkey's Electricity Generation in Europe in 2021</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">13.</span> <a href="#ComparisonofTurkeysElectricityGenerationwithItsNeighboringCountriesin2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Comparison of Turkey's Electricity Generation with Its Neighboring Countries in 2021</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">14.</span> <a href="#ElectricityGenerationbyEnergySources" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Electricity Generation by Energy Sources</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">15.</span> <a href="#RegionalChartsComparingAnnualRenewableEnergyProduction" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Regional Charts Comparing Annual Renewable Energy Production</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">16.</span> <a href="#ConclusionFinalThoughts&Insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Conclusion Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
import plotly.express as px
from matplotlib.font_manager import FontProperties
from IPython.display import HTML as html_print
from termcolor import colored
from scipy import stats

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the data Set</div></b>

# %%
df_3 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/03 modern-renewable-prod.csv")

# %%
df_3.head()
# Out:
#         Entity Code  Year  Electricity from wind (TWh)  \
# 0  Afghanistan  AFG  2000                        0.000
# 1  Afghanistan  AFG  2001                        0.000
# 2  Afghanistan  AFG  2002                        0.000
# 3  Afghanistan  AFG  2003                        0.000
# 4  Afghanistan  AFG  2004                        0.000
#
#    Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 0                         0.310                         0.000
# 1                         0.500                         0.000
# 2                         0.560                         0.000
# 3                         0.630                         0.000
# 4                         0.560                         0.000
#
#    Other renewables including bioenergy (TWh)
# 0                                       0.000
# 1                                       0.000
# 2                                       0.000
# 3                                       0.000
# ...

# %%
df_3.tail()
# Out:
#         Entity Code  Year  Electricity from wind (TWh)  \
# 8846  Zimbabwe  ZWE  2017                        0.000
# 8847  Zimbabwe  ZWE  2018                        0.000
# 8848  Zimbabwe  ZWE  2019                        0.000
# 8849  Zimbabwe  ZWE  2020                        0.000
# 8850  Zimbabwe  ZWE  2021                        0.000
#
#       Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 8846                         3.970                         0.010
# 8847                         5.050                         0.020
# 8848                         4.170                         0.030
# 8849                         3.810                         0.030
# 8850                         4.000                         0.040
#
#       Other renewables including bioenergy (TWh)
# 8846                                       0.320
# 8847                                       0.390
# 8848                                       0.380
# ...

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_3)
# Out:
# Shape
# (8851, 7)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_75d1c">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75d1c_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_75d1c_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_75d1c_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_75d1c_level0_col3" class="col_heading level0 col3" >Electricity from wind (TWh)</th>
#       <th id="T_75d1c_level0_col4" class="col_heading level0 col4" >Electricity from hydro (TWh)</th>
#       <th id="T_75d1c_level0_col5" class="col_heading level0 col5" >Electricity from solar (TWh)</th>
#       <th id="T_75d1c_level0_col6" class="col_heading level0 col6" >Other renewables including bioenergy (TWh)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75d1c_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
df_3 = df_3.drop(columns=['Code'])

# %%
df_3.head()
# Out:
#         Entity  Year  Electricity from wind (TWh)  \
# 0  Afghanistan  2000                        0.000
# 1  Afghanistan  2001                        0.000
# 2  Afghanistan  2002                        0.000
# 3  Afghanistan  2003                        0.000
# 4  Afghanistan  2004                        0.000
#
#    Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 0                         0.310                         0.000
# 1                         0.500                         0.000
# 2                         0.560                         0.000
# 3                         0.630                         0.000
# 4                         0.560                         0.000
#
#    Other renewables including bioenergy (TWh)
# 0                                       0.000
# 1                                       0.000
# 2                                       0.000
# 3                                       0.000
# 4                                       0.000

# %% [markdown]
# <a id='Total Renewable Energy Production Over the Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Renewable Energy Production Over the Years</div></b>

# %%
df_3['Total Renewable (TWh)'] = df_3[['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']].sum(axis=1)

colors = sns.color_palette("husl")

fig, ax = plt.subplots(figsize=(20, 8))

sns.lineplot(x='Year', y='Total Renewable (TWh)', data=df_3, marker='o', color=colors[0], ax=ax, label='Total Renewable Energy')

max_point = df_3[df_3['Total Renewable (TWh)'] == df_3['Total Renewable (TWh)'].max()]
ax.annotate(f"Max: {max_point['Year'].values[0]}", 
            xy=(max_point['Year'].values[0], max_point['Total Renewable (TWh)'].values[0]), 
            xytext=(-50, 50),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='black', lw=1),
            fontsize=12)

plt.title('Total Renewable Energy Production Over the Years', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Total Renewable Energy (TWh)', fontsize=12, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.6)

plt.legend(fontsize=12)

ax.axvspan(max_point['Year'].values[0] - 1, max_point['Year'].values[0] + 1, alpha=0.2, color='yellow')

font = FontProperties()
font.set_weight('bold')
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(ax.get_xticks(), fontproperties=font)
ax.set_yticklabels(ax.get_yticks(), fontproperties=font)

plt.xticks(rotation=45, fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This graph presents the total annual production of renewable energy, illustrating the aggregate contribution from wind, hydroelectric, solar, and other renewable sources. It highlights the year with the peak production value, emphasized with an annotation and arrow for clarity. The design of this graph effectively surfaces critical trends and pivot points in renewable energy production, offering an analytical foundation for long-term energy strategies.
#   </p>
# </div>

# %% [markdown]
# <a id='TotalRenewableEnergyProductionbySourceOvertheYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Renewable Energy Production by Source Over the Years</div></b>

# %%
energy_types = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

total_renewable_by_source_yearly = df_3.groupby('Year')[energy_types].sum().reset_index()

colors = ['dodgerblue', 'limegreen', 'gold', 'tomato']

plt.figure(figsize=(20, 8))

plt.stackplot(total_renewable_by_source_yearly['Year'], 
              total_renewable_by_source_yearly['Electricity from wind (TWh)'],
              total_renewable_by_source_yearly['Electricity from hydro (TWh)'],
              total_renewable_by_source_yearly['Electricity from solar (TWh)'],
              total_renewable_by_source_yearly['Other renewables including bioenergy (TWh)'],
              labels=['Electricity from wind (TWh)', 'Electricity from hydro (TWh', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)'], colors=colors)

plt.title('Total Renewable Energy Production by Source Over the Years')
plt.xlabel('Year')
plt.ylabel('Production (TWh)')
plt.legend(loc='upper left', title='Energy Sources')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This stacked area graph delineates the yearly aggregate production of renewable energy, segmented by source including wind, hydroelectric, solar, and bioenergy. The layering of data by color allows for a clear visual representation of the proportion each source contributes to the total, and how this has evolved over time. The use of distinct colors for each energy type makes it easy to identify trends and the growing significance of each renewable source within the overall energy mix. This visualization is instrumental in assessing the impact of each renewable energy source and guiding policy development for sustainable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='MostUsedRenewableEnergySourcebyCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Most Used Renewable Energy Source by Countries</div></b>

# %%
energy_types = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

latest_data = df_3.sort_values('Year').groupby('Entity').last().reset_index()

latest_data['Most Used Renewable Source'] = latest_data[energy_types].idxmax(axis=1)

color_map = {
    'Electricity from wind (TWh)': 'blue',
    'Electricity from hydro (TWh)': 'green',
    'Electricity from solar (TWh)': 'orange',
    'Other renewables including bioenergy (TWh)': 'red'
}
latest_data['Color'] = latest_data['Most Used Renewable Source'].map(color_map)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

merged = world.set_index('name').join(latest_data.set_index('Entity'))

color_map[np.nan] = 'lightgrey'
merged['Color'] = merged['Color'].fillna('lightgrey')

def add_legend(ax):
    legend_labels = {
        'blue': 'Wind Energy',
        'green': 'Hydropower Energy',
        'orange': 'Solar Energy',
        'red': 'Other Renewable Sources',
        'lightgrey': 'Data Missing or Not Available'
    }
    for color, label in legend_labels.items():
        ax.annotate(
            f'{label}: {color}',
            xy=(0.02, 0.02 + list(color_map.values()).index(color) * 0.03),
            xycoords='axes fraction',
            fontsize=10,
            color=color,
            weight='bold'
        )

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged.plot(color=merged['Color'], ax=ax, legend=False)
add_legend(ax)
ax.set_title('Most Used Renewable Energy Source by Countries')
ax.set_axis_off()

plt.show()
# Out:
# /tmp/ipykernel_19/652237926.py:15: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This geospatial visualization maps out the most used renewable energy source for each country, based on the latest available data. The map is color-coded to indicate the predominant type of renewable energy in each region: blue for wind, green for hydro, orange for solar, and red for other renewable sources. Countries with no data or insufficient data are marked in light grey. This visual tool provides a global perspective on renewable energy preferences, highlighting geographical trends and regional dependencies. It underscores the diverse energy landscape and helps to identify areas with potential for growth in certain types of renewable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='RankingofTopProducingCountriesforEachEnergySource'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Ranking of Top Producing Countries for Each Energy Source</div></b>

# %%
top_countries_by_source = {}
for energy_type in energy_types:
    top_countries = latest_data.sort_values(by=energy_type, ascending=False).head(5)
    top_countries_by_source[energy_type] = top_countries[['Entity', energy_type]]

fig, axes = plt.subplots(2, 2, figsize=(20, 16))
for i, (energy_type, df) in enumerate(top_countries_by_source.items()):
    ax = axes[i // 2, i % 2]
    sns.barplot(x=df[energy_type], y=df['Entity'], ax=ax, palette="viridis")
    ax.set_title(f'Top 5 Ülkeler - {energy_type}')
    ax.set_xlabel('Üretim (TWh)')
    ax.set_ylabel('Ülke')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This set of bar charts presents the top five countries in terms of production for each type of renewable energy: wind, hydro, solar, and other renewables. Each chart is dedicated to one energy type, showcasing countries that are leading in their respective renewable energy sectors. The vertical bars represent the production volume in terawatt-hours (TWh), offering a clear comparison of the leading countries’ contributions in each category. This visual comparison not only highlights the countries that are excelling in renewable energy production but also shows the varied focus and strengths in renewable energy across different nations. It's a valuable tool for understanding global renewable energy dynamics and recognizing key players in each sector.
#   </p>
# </div>

# %% [markdown]
# <a id='AnnualGrowthRatesinRenewableEnergyUse'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Annual Growth Rates in Renewable Energy Use</div></b>

# %%
energy_types = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 
                'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

total_renewable_comparison = df_3.groupby('Year')[energy_types].sum()
growth_rates = total_renewable_comparison.pct_change().multiply(100)

plt.figure(figsize=(20, 8))

palette = sns.color_palette("tab10", len(energy_types))

for i, energy_type in enumerate(energy_types):
    sns.lineplot(data=growth_rates, x=growth_rates.index, y=energy_type, label=energy_type, color=palette[i])

plt.title('Annual Growth Rates in Renewable Energy Use', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Growth (%)', fontsize=12)

plt.legend(title='Energy Sources')
plt.grid(True)

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph illustrates the annual growth rates of different types of renewable energy sources: wind, hydro, solar, and other renewables including bioenergy. Each line, color-coded for clarity, represents the percentage change in production from the previous year, allowing for a direct comparison of growth trajectories among different energy types. The graph provides a dynamic perspective on the evolving renewable energy sector, highlighting years of significant growth or decline. This analysis is crucial for understanding the momentum of renewable energy adoption and identifying which types of renewable energy are gaining traction or facing challenges.
#   </p>
# </div>

# %% [markdown]
# <a id='RegionalRenewableEnergyProduction'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Regional Renewable Energy Production</div></b>

# %%
selected_countries = ['Turkey', 'United States', 'China', 'Germany', 'Brazil', 'India', 'South Africa']

regional_data = latest_data[latest_data['Entity'].isin(selected_countries)]

fig = px.bar(regional_data, x='Entity', y='Total Renewable (TWh)', color='Entity',
             title='Regional Renewable Energy Production',
             labels={'Entity': 'Country', 'Total Renewable (TWh)': 'Total Renewable Energy Generation (TWh)'})

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart displays the total renewable energy generation in terawatt-hours (TWh) for selected countries: Turkey, United States, China, Germany, Brazil, India, and South Africa. Each country is represented by a different color, making it easy to distinguish their respective energy productions. The chart offers a comparative view of these countries' contributions to renewable energy, highlighting the variations and scale of their renewable energy sectors. It's an effective visual tool to understand the renewable energy landscape in key regions and to identify leading and emerging players in the field of sustainable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyTrendsinDevelopingCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Trends in Developing Countries</div></b>

# %%
developing_countries = ['India', 'Brazil', 'Nigeria', 'Vietnam', 'Indonesia', 'Turkey']

developing_countries_data = df_3[df_3['Entity'].isin(developing_countries)]

plt.figure(figsize=(20, 10))

for country in developing_countries:
    country_data = developing_countries_data[developing_countries_data['Entity'] == country]
    plt.plot(country_data['Year'], country_data['Total Renewable (TWh)'], label=country, marker='o')

plt.title('Renewable Energy Trends in Developing Countries', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Total Renewable Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph illustrates the renewable energy trends in developing countries, including India, Brazil, Nigeria, Vietnam, and Indonesia. Each country is represented by a line with markers, indicating the total renewable energy generation in terawatt-hours (TWh) over the years. The graph provides a clear visualization of the growth patterns in renewable energy within these nations, highlighting both the progress made and the challenges faced. The varying trajectories of each country offer insights into how different developing nations are adopting and investing in renewable energy technologies, reflecting their unique economic, geographic, and policy contexts.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyTrendsinDevelopedCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Trends in Developed Countries</div></b>

# %%
developed_countries = ['China', 'United States', 'India', 'Germany', 'Brazil', 'South Africa', 'Australia', 'Russia']

developed_countries_data = df_3[df_3['Entity'].isin(developed_countries)]

plt.figure(figsize=(15, 10))

for country in developed_countries:
    country_data = developed_countries_data[developed_countries_data['Entity'] == country]
    plt.plot(country_data['Year'], country_data['Total Renewable (TWh)'], label=country, marker='o')

plt.title('Renewable Energy Trends in Developed Countries')
plt.xlabel('Year')
plt.ylabel('Total Renewable Energy Generation (TWh)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This graph showcases the trends in renewable energy generation across a selection of developed countries, including China, United States, India, Germany, Brazil, South Africa, Australia, and Russia. Each country's yearly renewable energy production, measured in terawatt-hours (TWh), is represented by a distinct line with markers. The graph provides a comparative view of how these countries have developed and expanded their renewable energy sectors over time. It highlights the progress made in renewable energy production, as well as the varying scales and rates of growth among these nations. This visualization is crucial for understanding the advancements in the renewable energy field among developed nations and for identifying global leaders and innovators in this sector.
#   </p>
# </div>

# %% [markdown]
# <a id='RelationshipBetweenRenewableEnergySources'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Relationship Between Renewable Energy Sources</div></b>

# %%
global_renewable_production = df_3.groupby('Year')[energy_types].sum()

renewable_share = global_renewable_production.div(global_renewable_production.sum(axis=1), axis=0) * 100

colors = px.colors.qualitative.Plotly

fig = px.line(
    renewable_share,
    x=renewable_share.index,
    y=energy_types,
    labels={'index': 'Year', 'value': 'Percentage in Total Production (%)'},
    title='Relationship Between Renewable Energy Sources'
)

for i, energy_type in enumerate(energy_types):
    fig.data[i].line.color = colors[i]

fig.update_layout(legend_title_text='Energy Sources')
fig.show()
# Out:
# <div>                            <div id="e6520912-7698-4baa-baa4-9791d71d4d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6520912-7698-4baa-baa4-9791d71d4d27")) {                    Plotly.newPlot(                        "e6520912-7698-4baa-baa4-9791d71d4d27",                        [{"hovertemplate":"variable=Electricity from wind (TWh)\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage in Total Production (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electricity from wind (TWh)","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Electricity from wind (TWh)","orientation":"v","showlegend":true,"x":[1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,19
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph depicts the relationship between various renewable energy sources (wind, hydro, solar, and other renewables) as a percentage of the total global renewable energy production over time. Each energy type is represented by a line in a distinct color, illustrating its share in the total renewable energy mix. The graph highlights how the contribution of each renewable source to the overall energy production has changed year by year. It provides a clear understanding of the evolving dynamics in the renewable energy sector, showing which sources are gaining prominence and how the balance between different types of renewable energy is shifting. This analysis is essential for comprehending the global trends in renewable energy and for strategic planning in energy policies.
#   </p>
# </div>

# %% [markdown]
# <a id='TurkeysElectricityGenerationbyEnergySourcesin2000-2022'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Turkey's Electricity Generation by Energy Sources in 2000-2022 </div></b>

# %%
turkey_data = df_3[df_3['Entity'] == 'Turkey']

start_year = 2000
end_year = 2023  

data_year_range = turkey_data[(turkey_data['Year'] >= start_year) & (turkey_data['Year'] < end_year)]

sources = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

energy_production = data_year_range[sources].sum()

energy_df = pd.DataFrame({'Source': sources, 'Production': energy_production})
energy_df = energy_df.sort_values(by='Production', ascending=False)

fig = px.bar(
    energy_df, 
    x='Source', 
    y='Production', 
    title=f"Turkey's Electricity Generation by Energy Sources between {start_year}-{end_year-1}",
    labels={'Production': 'Electricity Generation (TWh)'}
)

colors = px.colors.qualitative.Plotly[:len(sources)]
fig.update_traces(marker=dict(color=colors))

fig.show()
# Out:
# <div>                            <div id="76b8f55e-7055-47f0-9f97-3e95b7c45974" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76b8f55e-7055-47f0-9f97-3e95b7c45974")) {                    Plotly.newPlot(                        "76b8f55e-7055-47f0-9f97-3e95b7c45974",                        [{"alignmentgroup":"True","hovertemplate":"Source=%{x}\u003cbr\u003eElectricity Generation (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Electricity from hydro (TWh)","Electricity from wind (TWh)","Other renewables including bioenergy (TWh)","Electricity from solar (TW
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart illustrates Turkey's electricity generation from various renewable sources between 2000 and 2022. It details the production in terawatt-hours (TWh) from wind, hydro, solar, and other renewable sources including bioenergy. Each source is represented by a bar, color-coded for easy distinction. The chart provides a clear view of which renewable energy sources have been the most productive in Turkey during this period. It helps in understanding the country's energy mix and priorities in renewable energy, showing how different sources contribute to the overall energy landscape. This visualization is crucial for analyzing Turkey's progress in renewable energy and for strategic energy planning and policy-making.
#   </p>
# </div>

# %% [markdown]
# <a id='DistributionofRenewableEnergySourcesinTurkeysElectricityGenerationbetween2018-2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Distribution of Renewable Energy Sources in Turkey's Electricity Generation between 2018-2021 </div></b>

# %%
sources = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

turkey_data = df_3[df_3['Entity'] == 'Turkey']

years = [2018, 2019, 2020, 2021]

plt.figure(figsize=(20, 20))
for i, year in enumerate(years):
    data_year = turkey_data[turkey_data['Year'] == year]
    energy_production = data_year[sources].values[0]
    plt.subplot(2, 2, i+1)
    patches, texts, autotexts = plt.pie(energy_production, labels=sources, autopct='%1.1f%%', startangle=140)
    
    for text in texts:
        text.set_fontsize(12)
        text.set_weight('bold')
    for autotext in autotexts:
        autotext.set_fontsize(12)
        autotext.set_weight('bold')
    
    plt.title(f'Electricity Production Distribution in Turkey for the Year {year}', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This series of pie charts provides a year-by-year breakdown of Turkey's electricity production from renewable sources for the years 2018, 2019, 2020, and 2021. Each chart represents the percentage distribution of electricity generated from wind, hydro, solar, and other renewable sources including bioenergy for a specific year. The data is presented in a visually engaging format, with each sector of the pie chart labeled and quantified, enabling an easy comparison of the contribution of each energy source annually. The bold and clear labels help in quickly identifying the changes in Turkey's renewable energy mix over these years. This visualization is valuable for observing shifts in energy preference and policy impact in Turkey's journey towards sustainable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='ComparisonofTurkeysElectricityGenerationinEuropein2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Comparison of Turkey's Electricity Generation in Europe in 2021 </div></b>

# %%
renewable_sources = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']
selected_year = 2021
countries = ['Turkey', 'Germany', 'United Kingdom', 'Greece', 'France', 'Italy', 'Spain', 'Netherlands', 'Sweden', 'Poland', 'Portugal']

filtered_data = df_3[(df_3['Year'] == selected_year) & (df_3['Entity'].isin(countries))]

fig = px.bar(filtered_data, x='Entity', y=renewable_sources,
             title=f'Comparison of Electricity Generation in European Countries in {selected_year}',
             labels={'Entity': 'Countries', 'value': 'Electricity Generation (TWh)'},
             color_discrete_sequence=['green', 'blue', 'yellow', 'brown'])

fig.update_layout(xaxis_tickangle=-45, xaxis_title=None, yaxis_title='Electricity Generation (TWh)',
                  title_font=dict(size=20))

fig.show()
# Out:
# <div>                            <div id="df05e548-aebc-4709-9eb7-811f21af7aee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df05e548-aebc-4709-9eb7-811f21af7aee")) {                    Plotly.newPlot(                        "df05e548-aebc-4709-9eb7-811f21af7aee",                        [{"alignmentgroup":"True","hovertemplate":"variable=Electricity from wind (TWh)\u003cbr\u003eCountries=%{x}\u003cbr\u003eElectricity Generation (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electricity from wind (TWh)","marker":{"color":"green","pattern":{"shape":""}},"name":"Electricity from wind (TWh)","offsetgroup":"Electricity from wind (TWh)","orientation":"v","showlegend":true,"textposition":"auto","x":["France","Germany","Greece","Italy
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart offers a comparative view of electricity generation from various renewable sources in several European countries for the year 2021. The countries included are Turkey, Germany, United Kingdom, Greece, France, Italy, Spain, Netherlands, Sweden, Poland, and Portugal. Each bar is segmented to show the contribution of different renewable sources – wind, hydro, solar, and other renewables including bioenergy – to the total electricity generation in terawatt-hours (TWh). The distinct color segments within each bar provide a clear visual representation of the energy mix in each country, highlighting the diversity and reliance on various renewable sources. This chart is particularly useful for understanding the renewable energy landscape in Europe, showing how different countries prioritize and develop various forms of renewable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='ComparisonofTurkeysElectricityGenerationwithItsNeighboringCountriesin2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Comparison of Turkey's Electricity Generation with Its Neighboring Countries in 2021 </div></b>

# %%
selected_year = 2021
neighboring_countries = ['Turkey', 'Greece', 'Bulgaria', 'Georgia', 'Armenia', 'Azerbaijan', 'Iran', 'Iraq', 'Syria']
renewable_sources = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)', 'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

filtered_data = df_3[(df_3['Year'] == selected_year) & (df_3['Entity'].isin(neighboring_countries))]

colors = ['green', 'blue', 'yellow', 'brown']

fig = px.bar(filtered_data, x='Entity', y=renewable_sources,
             title=f'Comparison of Turkey\'s Electricity Generation with Its Neighboring Countries in {selected_year}',
             labels={'Entity': 'Countries', 'value': 'Electricity Generation (TWh)'},
             color_discrete_sequence=colors)

fig.update_layout(xaxis_tickangle=-45, xaxis_title=None, yaxis_title='Electricity Generation (TWh)',
                  title_font=dict(size=20))

fig.show()
# Out:
# <div>                            <div id="6286d833-f3c9-43f6-92af-75223f13da76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6286d833-f3c9-43f6-92af-75223f13da76")) {                    Plotly.newPlot(                        "6286d833-f3c9-43f6-92af-75223f13da76",                        [{"alignmentgroup":"True","hovertemplate":"variable=Electricity from wind (TWh)\u003cbr\u003eCountries=%{x}\u003cbr\u003eElectricity Generation (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electricity from wind (TWh)","marker":{"color":"green","pattern":{"shape":""}},"name":"Electricity from wind (TWh)","offsetgroup":"Electricity from wind (TWh)","orientation":"v","showlegend":true,"textposition":"auto","x":["Armenia","Azerbaijan","Bulgaria",
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart provides a comparative analysis of electricity generation from renewable sources in Turkey and its neighboring countries (Greece, Bulgaria, Georgia, Armenia, Azerbaijan, Iran, Iraq, and Syria) for the year 2021. Each country's total electricity generation is divided into segments representing different renewable sources – wind, hydro, solar, and other renewables including bioenergy. The color-coded bars allow for an easy comparison of the energy mix and the scale of renewable energy production in each country. This visualization highlights the varying degrees of renewable energy adoption among these neighboring nations and offers insights into regional energy strategies and resource utilization. The chart underscores the diversity in renewable energy deployment across the region, reflecting different geographical, climatic, and policy influences.
#   </p>
# </div>

# %% [markdown]
# <a id='ElectricityGenerationbyEnergySources'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Electricity Generation by Energy Sources </div></b>

# %%
energy_sources = ['Electricity from wind (TWh)', 'Electricity from hydro (TWh)',
                  'Electricity from solar (TWh)', 'Other renewables including bioenergy (TWh)']

total_generation = df_3[energy_sources].sum()
total_generation = total_generation.sort_values(ascending=False)

total_generation_df = pd.DataFrame({'Energy Source': total_generation.index, 'Electricity Generation (TWh)': total_generation.values})

colors = {
    'Electricity from wind (TWh)': 'green',
    'Electricity from hydro (TWh)': 'blue',
    'Electricity from solar (TWh)': 'yellow',
    'Other renewables including bioenergy (TWh)': 'brown',
}

total_generation_df['Color'] = total_generation_df['Energy Source'].map(colors)

fig = px.bar(total_generation_df, x='Energy Source', y='Electricity Generation (TWh)',
             title='Electricity Generation by Energy Sources',
             labels={'Energy Source': 'Energy Source', 'Electricity Generation (TWh)': 'Electricity Generation (TWh)'},
             color='Color')

fig.update_layout(title_font=dict(size=20),
                  xaxis_title_font=dict(size=16),
                  yaxis_title_font=dict(size=16))

fig.show()
# Out:
# <div>                            <div id="a80411b0-0153-434a-962a-296b33873c81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a80411b0-0153-434a-962a-296b33873c81")) {                    Plotly.newPlot(                        "a80411b0-0153-434a-962a-296b33873c81",                        [{"alignmentgroup":"True","hovertemplate":"Color=blue\u003cbr\u003eEnergy Source=%{x}\u003cbr\u003eElectricity Generation (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"blue","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"blue","offsetgroup":"blue","orientation":"v","showlegend":true,"textposition":"auto","x":["Electricity from hydro (TWh)"],"xaxis":"x","y":[1030553.98796953],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hove
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart visualizes the total electricity generation from various renewable energy sources. The chart categorizes the global production into wind, hydro, solar, and other renewable sources including bioenergy. Each category is represented by a different color, providing a clear visual distinction. The chart ranks the energy sources based on their total electricity generation in terawatt-hours (TWh), allowing for a straightforward comparison of the relative contributions of each source. This visualization effectively highlights the dominance or prevalence of certain renewable sources over others in the global energy mix. It offers valuable insights into the current state of renewable energy production and indicates areas of potential growth or focus for future energy policies and investments.
#   </p>
# </div>

# %% [markdown]
# <a id='RegionalChartsComparingAnnualRenewableEnergyProduction'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'> Regional Charts Comparing Annual Renewable Energy Production </div></b>

# %%
selected_regions = ['Africa', 'Asia', 'Europe', 'North America', 'South America']
filtered_data = df_3[df_3['Entity'].isin(selected_regions)]

grouped_data = filtered_data.groupby(['Year', 'Entity']).sum().reset_index()

sns.set(style="whitegrid")
plt.figure(figsize=(17, 12))

plt.subplot(2, 2, 1)
sns.lineplot(data=grouped_data, x='Year', y='Electricity from wind (TWh)', hue='Entity')
plt.title('Electricity from Wind by Region', fontweight='bold')
plt.ylabel('Electricity (TWh)', fontweight='bold')
plt.xlabel('Year', fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

plt.subplot(2, 2, 2)
sns.lineplot(data=grouped_data, x='Year', y='Electricity from hydro (TWh)', hue='Entity')
plt.title('Electricity from Hydro by Region', fontweight='bold')
plt.ylabel('Electricity (TWh)', fontweight='bold')
plt.xlabel('Year', fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

plt.subplot(2, 2, 3)
sns.lineplot(data=grouped_data, x='Year', y='Electricity from solar (TWh)', hue='Entity')
plt.title('Electricity from Solar by Region', fontweight='bold')
plt.ylabel('Electricity (TWh)', fontweight='bold')
plt.xlabel('Year', fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

plt.subplot(2, 2, 4)
sns.lineplot(data=grouped_data, x='Year', y='Other renewables including bioenergy (TWh)', hue='Entity')
plt.title('Other Renewable Energy by Region', fontweight='bold')
plt.ylabel('Electricity (TWh)', fontweight='bold')
plt.xlabel('Year', fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This set of four line graphs illustrates the electricity generation from different renewable sources across various regions – Africa, Asia, Europe, North America, and South America. Each graph focuses on one type of renewable energy: wind, hydro, solar, and other renewables including bioenergy. The graphs track the annual electricity production in terawatt-hours (TWh) from these sources over several years, differentiated by region. The data is presented with distinct colors for each region, making it easy to follow and compare the trends across different areas. These graphs provide a comprehensive overview of how different regions are utilizing various renewable energy sources, indicating their growth, potential, and regional preferences. The visualization effectively displays the diverse approaches to renewable energy across the globe and highlights regions that are leading or emerging in specific renewable sectors.
#   </p>
# </div>

# %% [markdown]
# <a id='ConclusionFinalThoughts&Insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Conclusion Final Thoughts & Insights:</strong> This analysis provides a comprehensive portrait of renewable energy across the globe. It delves into the evolution of renewable energy's share over time, its distribution among countries and regions, identifies leaders and laggards, and explores continental distribution and growth dynamics. The graphs vividly demonstrate the growth of renewable energy in recent years, highlighting the countries that have made significant strides, the worldwide distribution, and the continents that have either surged ahead or lagged. The analysis includes an examination of Turkey's renewable energy profile and a comparative review with European countries and neighboring regions.
#
#     The increasing role of renewable energy in the global energy portfolio is evident, with growth patterns varying across the world, presenting unique trends and opportunities. This analysis furnishes valuable insights for policymakers, energy sector experts, and researchers, aiding in shaping the future of sustainable energy.
#   </p>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/04-global-transition-to-sustainable-energy/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
