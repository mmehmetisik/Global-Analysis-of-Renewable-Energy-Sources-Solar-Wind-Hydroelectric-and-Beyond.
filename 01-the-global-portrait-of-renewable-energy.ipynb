# %% [markdown]
# <div style="border: 15px solid #4A148C; border-radius: 30px; padding: 250px 30px 250px 30px; box-shadow: 5px 5px 15px grey; background-image: url('https://cdn.vox-cdn.com/thumbor/llF7m1WSFgGoNTup0LbPtukpPWs=/1400x1050/filters:format(jpeg)/cdn.vox-cdn.com/uploads/chorus_asset/file/16278196/shutterstock_581537176.jpg'); background-size: cover; background-position: center;">
#     <div style="padding: 0; margin: -220px 0 0 0;">
#         <h1 style="font-size: 42px; font-weight: bold; color: #FF5733; text-align: center; border-bottom: 6px ridge #FFC107; font-family: 'Georgia'; padding: 20px; background: linear-gradient(135deg, rgba(255,255,204,0.6) 0%, rgba(204,204,255,0.6) 100%); text-shadow: 3px 3px 6px #888888;">The Global Portrait of Renewable Energy</h1>
#         <h2 style="font-size: 32px; font-weight: bold; color: #900C3F; text-align: center; font-family: 'Times New Roman'; padding: 15px; background: linear-gradient(135deg, rgba(255,255,255,0.6) 30%, rgba(255,228,228,0.6) 100%); border-radius: 20px; box-shadow: 5px 5px 10px grey;">Solar, Wind, Hydro, and More</h2>
#     </div>
# </div>

# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 40px 20px 40px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h1 style="font-size: 32px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">The Global Progress of Renewable Energy:</h1>
#     <h2 style="font-size: 24px; font-weight: bold; color: #8B0000; text-align: center; font-family: 'Times New Roman'; padding: 10px;">A Regional and Temporal Analysis</h2>
# </div>

# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">🌍 Business Problem</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;"><strong>Renewable energy</strong> plays a significant role globally in building a <strong>sustainable future</strong>. Understanding how the use of renewable energy sources has changed in various regions over different time periods can be of critical importance to policymakers, energy companies, and investors. This dataset contains the percentage of renewable energy from <strong>1965 to the present day</strong> across different regions.</p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li>📊 <strong>Regional and Temporal Analyses:</strong> Determine which regions have made the fastest transition to renewable energy, what strategies have been most effective, and where future investments need to be directed.</li>
#         <li>🎯 <strong>Sustainable Energy Goals:</strong> This analysis can be an essential step in achieving goals, assist in optimizing energy costs.</li>
#         <li>🌱 <strong>Environmental Impact:</strong> Contribute to developing strategies to reduce impact, moving towards a greener planet.</li>
#     </ul>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">The insights derived from this dataset not only shed light on the past trends but also help to forge the path towards a cleaner and more responsible energy future.</p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #FFA500; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #FFA500; font-family: 'Georgia'; padding: 10px;">📊 Dataset Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">The dataset contains a total of <strong>5603 observations</strong> and <strong>4 variables</strong>.</p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Indicates the region name. There are a total of 104 different regions (e.g., "Africa").</li>
#         <li><strong>Code:</strong> Contains region codes. Some values may be missing, and there are a total of 81 different codes.</li>
#         <li><strong>Year:</strong> Shows the analyzed year, ranging from 1965 to 2021.</li>
#         <li><strong>Renewables (% equivalent primary energy):</strong> Represents the percentage of renewable energy in total energy for that region and year. This ratio varies between 0% and 86.87%.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#renewable-energy-share-over-time-equivalent-primary-energy" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share Over Time (% equivalent primary energy)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#renewable-energy-share-worldwide" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share Worldwide (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#top-20-countries-regions-renewable-energy-share-last-6-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Top 20 Countries/Regions in Renewable Energy Share Over the Last 6 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#overall-distribution-renewable-energy-share" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Overall Distribution of Renewable Energy Share</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#renewable-energy-share-major-regions" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share in Major Regions (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#lowest-renewable-energy-share-countries-last-6-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">10 Countries/Regions with the Lowest Renewable Energy Share in the Last 6 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#distribution-renewable-energy-share-continent" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Distribution of Renewable Energy Share by Continent</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#renewable-energy-share-trend-worldwide" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share Trend Worldwide (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#renewable-energy-share-comparison-continents" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share Comparison Among Continents (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#renewable-energy-share-developed-developing-continents" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share in Developed and Developing Continents (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#average-annual-renewable-energy-growth-rates-continent" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Average Annual Renewable Energy Growth Rates by Continent (%)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#fastest-growing-countries-renewable-energy-share-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Top 5 Fastest-Growing Countries in Renewable Energy Share (Last 10 Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">13.</span> <a href="#analysis-bottom-5-countries-renewable-energy-share-decline-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Analysis of the Bottom 5 Countries in Renewable Energy Share Decline (Last 10 Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">14.</span> <a href="#average-renewable-energy-share-country-europe-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Average Renewable Energy Share by Country in Europe (Last 10 Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">15.</span> <a href="#renewable-energy-usage-developing-developed-countries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Usage in Developing and Developed Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">16.</span> <a href="#renewable-energy-share-trend-turkey-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Share Trend in Turkey Over the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">17.</span> <a href="#annual-percentage-change-renewable-energy-share-turkey-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Annual Percentage Change in Renewable Energy Share in Turkey Over the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">18.</span> <a href="#average-renewable-energy-share-europe-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Average Renewable Energy Share in Europe Over the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">19.</span> <a href="#average-renewable-energy-share-turkey-neighboring-countries-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Average Renewable Energy Share in Turkey and Neighboring Countries Over the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">20.</span> <a href="#average-renewable-energy-share-turkey-neighboring-countries-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Average Renewable Energy Share in Turkey and Neighboring Countries Over the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">21.</span> <a href="#Conclusion-Final-Thoughts-&-Insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Conclusion Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
from IPython.display import HTML as html_print
from termcolor import colored
from scipy import stats
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the data Set</div></b>

# %%
df_1 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/01 renewable-share-energy.csv")

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
df_1.head(10)
# Out:
#    Entity Code  Year  Renewables (% equivalent primary energy)
# 0  Africa  NaN  1965                                     5.747
# 1  Africa  NaN  1966                                     6.122
# 2  Africa  NaN  1967                                     6.326
# 3  Africa  NaN  1968                                     7.005
# 4  Africa  NaN  1969                                     7.956
# 5  Africa  NaN  1970                                     9.162
# 6  Africa  NaN  1971                                     8.131
# 7  Africa  NaN  1972                                     8.748
# 8  Africa  NaN  1973                                     8.542
# 9  Africa  NaN  1974                                     9.268

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_1)
# Out:
# Shape
# (5603, 4)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_6c35f">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c35f_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_6c35f_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_6c35f_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_6c35f_level0_col3" class="col_heading level0 col3" >Renewables (% equivalent primary energy)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c35f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c35f_row0_col0" class="data row0 col0" >Africa</td>
#       <td id="T_6c35f_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_6c35f_row0_col2" class="data row0 col2" >1965</td>
#       <td id="T_6c35f_row0_col3" class="data row0 col3" >5.747495</td>
#     </tr>
#     <tr>
# ...

# %%
df_1 = df_1.drop(columns=['Code'])

# %%
df_1.head()
# Out:
#    Entity  Year  Renewables (% equivalent primary energy)
# 0  Africa  1965                                     5.747
# 1  Africa  1966                                     6.122
# 2  Africa  1967                                     6.326
# 3  Africa  1968                                     7.005
# 4  Africa  1969                                     7.956

# %%
df_1.isnull().sum()
# Out:
# Entity                                      0
# Year                                        0
# Renewables (% equivalent primary energy)    0
# dtype: int64

# %% [markdown]
# <a id='renewable-energy-share-over-time-equivalent-primary-energy'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share Over Time (% equivalent primary energy)</div></b>

# %%
title_font_size = 18
label_font_size = 14
line_width = 2.5

plt.figure(figsize=(20, 8))
sns.lineplot(x='Year', y='Renewables (% equivalent primary energy)', data=df_1, linewidth=line_width, color='steelblue')

plt.title('Renewable Energy Share Over Time (% equivalent primary energy)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Share (%)', fontsize=label_font_size, fontweight='bold')

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph shows the percentage change in the global share of renewable energy between 1965 and 2021. The observed upward trend reflects that renewable energy has become increasingly popular and widespread as an energy source during this period. This trend may have been shaped by the growing importance of sustainable energy sources and the influence of technological advancements.</p>
#         <p>Some fluctuations in the line of the graph indicate moments when the increase was interrupted or showed variability. These fluctuations might stem from economic, political, or technological changes that occurred in specific years.</p>
#         <p>In conclusion, this graph concretely illustrates the rise of renewable energy worldwide. However, the wavering of the line reminds us that the proliferation of renewable energy is a complex and multi-dimensional process. This type of analysis could be of critical importance in shaping energy policies, encouraging technological innovations, and building a sustainable future.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-share-worldwide'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share Worldwide (%)</div></b>

# %%
world_data = df_1[df_1['Entity'] == 'World']

plt.figure(figsize=(20, 8))
plt.plot(world_data['Year'], world_data['Renewables (% equivalent primary energy)'], label="World", linewidth=line_width, color='darkorange')

plt.title('Renewable Energy Share Worldwide (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')

plt.legend(fontsize=label_font_size)

plt.grid(True, linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>Focusing on this graph, we can observe the percentage change in the global share of renewable energy between 1965 and 2021. While the renewable energy share was relatively low in the initial years, there has been a noticeable increase in recent times. This rise reflects renewable energy's growing role in combating climate change and forming a sustainable energy future.</p>
#         <p>The technological advancements and increasing global commitment to renewable energy may be the driving forces behind this positive trend. This upward shift worldwide can be seen as a promising sign for the future but also emphasizes the critical importance of ongoing efforts and investments in this field.</p>
#         <p>This analysis could be valuable in shaping energy policies, making investment decisions, and determining environmental sustainability strategies.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='top-20-countries-regions-renewable-energy-share-last-6-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 20 Countries/Regions in Renewable Energy Share Over the Last 6 Years</div></b>

# %%
latest_6_years = df_1['Year'].unique()[-6:]

filtered_data = df_1[df_1['Year'].isin(latest_6_years)]

top_20_per_year = filtered_data.groupby('Year').apply(lambda x: x.nlargest(20, 'Renewables (% equivalent primary energy)'))

pivot_data = top_20_per_year.pivot(index='Entity', columns='Year', values='Renewables (% equivalent primary energy)').fillna(0)

sorted_pivot_data = pivot_data.sum(axis=1).sort_values(ascending=False)

sorted_pivot_data = pivot_data.loc[sorted_pivot_data.index]

fig, ax = plt.subplots(figsize=(20, 12))
sorted_pivot_data.plot(kind='bar', stacked=True, ax=ax, colormap='viridis', edgecolor='white', width=0.7)
ax.set_title('Top 20 Countries/Regions for Renewable Energy Share in the Last 6 Years', fontsize=18, fontweight='bold')
ax.set_xlabel('Country/Region', fontsize=14, fontweight='bold')
ax.set_ylabel('Renewable Energy Share (%)', fontsize=14, fontweight='bold')
ax.legend(title='Year', fontsize=10)
plt.xticks(rotation=90)
plt.tight_layout()

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This set of graphs illustrates the percentage change in the renewable energy share among the top 20 countries/regions worldwide over the last six years. A separate horizontal bar chart is created for each year, highlighting the countries/regions with the highest renewable energy share for that year.</p>
#         <p>These charts can help us understand how renewable energy is changing globally and which countries/regions are leading in this field. Additionally, we can observe which countries/regions are rising or falling in the rankings over the years.</p>
#         <p>This type of analysis can assist governments, policymakers, and investors in better understanding renewable energy trends and dynamics. It can also provide insights into the future development of renewable energy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='overall-distribution-renewable-energy-share'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Overall Distribution of Renewable Energy Share</div></b>

# %%
mean_val = df_1['Renewables (% equivalent primary energy)'].mean()
median_val = df_1['Renewables (% equivalent primary energy)'].median()

plt.figure(figsize=(22, 10), facecolor='#EAEAF2')

sns.histplot(df_1['Renewables (% equivalent primary energy)'], bins=20, edgecolor='black', color='#3498db', kde=False, label="Frequency", linewidth=1.5, alpha=0.9, zorder=2)

sns.kdeplot(df_1['Renewables (% equivalent primary energy)'], color='red', lw=3, label="Density", zorder=3)

plt.axvline(mean_val, color='green', linestyle='--', lw=2, label=f'Mean: {mean_val:.2f}%', zorder=4)
plt.axvline(median_val, color='blue', linestyle='--', lw=2, label=f'Median: {median_val:.2f}%', zorder=4)

title_font_size = 21
label_font_size = 16
plt.title('Overall Distribution of Renewable Energy Share', fontsize=title_font_size, fontweight='bold', pad=20, backgroundcolor='#EAEAF2')
plt.xlabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Frequency', fontsize=label_font_size, fontweight='bold')
plt.legend(fontsize=label_font_size, loc="upper right")

plt.grid(axis='y', linestyle='-', linewidth=0.7, alpha=0.7, zorder=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This histogram displays the percentage distribution of renewable energy share across various countries and years worldwide.</p>
#         <p>The graph is segmented into 20 percentage intervals, each representing a specific range of renewable energy share. The majority of the data points fall into lower percentage values. However, there are also observations in the higher percentage ranges.</p>
#         <p>The concentration in the lower percentage values suggests that renewable energy might be less prevalent in some countries or periods. The presence of higher values indicates that renewable energy might play a significant role in certain regions or times.</p>
#         <p>The density graph (depicted by the red line) provides a continuous distribution of the renewable energy share, highlighting which percentage ranges are particularly dense.</p>
#         <p>The mean (represented by the green dashed line) and median (blue dashed line) provide insights into the overall trend of renewable energy share. The proximity of the mean and median suggests that the distribution might be symmetric.</p>
#         <p>This graph offers a comprehensive view of how renewable energy is distributed globally, indicating regions or years where it's more prevalent and the general direction of the trend.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-share-major-regions'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share in Major Regions (%)</div></b>

# %%
regions = ['World', 'Africa', 'Asia', 'Europe', 'North America', 'South America']

plt.figure(figsize=(20, 8), facecolor='whitesmoke')
for region in regions:
    region_data = df_1[df_1['Entity'] == region]
    plt.plot(region_data['Year'], region_data['Renewables (% equivalent primary energy)'], label=region, linewidth=line_width)


plt.title('Renewable Energy Share in Major Regions (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')


plt.legend(fontsize=label_font_size)


plt.grid(True, linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This line chart illustrates the percentage change in renewable energy share over time in the world and some major regions (Africa, Asia, Europe, North America, South America). By using a separate line for each region, we can understand the differences and trends among the regions.</p>
#         <p>The graph shows that the renewable energy share has significantly increased over time in some regions, reflecting the growing interest and investment in renewable energy in these areas. In other regions, a more stagnant profile may be observed, indicating that renewable energy may have been adopted more slowly.</p>
#         <p>This type of analysis can help us understand how renewable energy is changing globally and across different regions. It can also provide insights into how renewable energy policies and strategies should be shaped in specific regions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='lowest-renewable-energy-share-countries-last-6-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>10 Countries/Regions with the Lowest Renewable Energy Share in the Last 6 Years</div></b>

# %%
latest_6_years = df_1['Year'].unique()[-6:]

heatmap_data = pd.DataFrame()

for year in latest_6_years:
    specific_year_data = df_1[df_1['Year'] == year]
    bottom_countries_year = specific_year_data.nsmallest(10, 'Renewables (% equivalent primary energy)')
    heatmap_data[year] = bottom_countries_year.set_index('Entity')['Renewables (% equivalent primary energy)']

title_font_size = 21
label_font_size = 16

plt.figure(figsize=(16, 10))
sns.heatmap(heatmap_data, cmap='YlOrRd', annot=True, linewidths=0.5, linecolor='gray', cbar_kws={'label': 'Renewable Energy Share (%)'})
plt.title('Renewable Energy Share in Bottom 10 Countries/Regions', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Country/Region', fontsize=label_font_size, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This heatmap showcases the bottom 10 countries/regions in terms of the percentage of renewable energy share over the last six years.</p>
#         <p>Darker shades indicate lower renewable energy shares, while lighter shades represent higher shares. This is achieved with the 'YlOrRd' color palette, which transitions from yellow to orange to red. On the vertical axis, the 10 countries/regions with the lowest percentage of renewable energy share are listed. These countries/regions might have made relatively less progress in renewable energy over these years or might face challenges accessing renewable energy sources.</p>
#         <p>The horizontal axis displays the last six years. For each year, the 10 countries/regions with the lowest renewable energy share within that year are chosen. The colors depicted on the heatmap indicate that some countries/regions consistently have a low renewable energy share over the last six years. Moreover, there seem to be minimal fluctuations in some countries, indicating a stable performance in renewable energy.</p>
#         <p>Such visualization can be beneficial for policymakers, researchers, and investors. They can use this dataset to identify which countries require support or investment in the realm of renewable energy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-renewable-energy-share-continent'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Share by Continent</div></b>

# %%
continents = ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania']

sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set_palette("muted")

plt.figure(figsize=(24, 10), facecolor='whitesmoke')

for continent, color in zip(continents, sns.color_palette()):
    continent_data = df_1[df_1['Entity'] == continent]
    ax = sns.kdeplot(continent_data['Renewables (% equivalent primary energy)'], fill=True, label=continent, color=color, alpha=0.7)
    
    y = continent_data['Renewables (% equivalent primary energy)'].values
    x = np.linspace(min(y), max(y), 100)
    kde = stats.gaussian_kde(y)
    max_density_value = x[np.argmax(kde(x))]
    
    plt.text(max_density_value, kde(max_density_value), f'{round(max_density_value, 2)}%', fontsize=10, verticalalignment='bottom', horizontalalignment='right', color=color)

plt.title('Distribution of Renewable Energy Share by Continent', fontsize=title_font_size + 2, fontweight='bold')
plt.xlabel('Renewable Energy Share (%)', fontsize=label_font_size + 1, fontweight='bold')
plt.ylabel('Density', fontsize=label_font_size + 1, fontweight='bold')
plt.legend(loc='upper right', fontsize='medium')

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This histogram chart illustrates the percentage distribution of renewable energy share across different continents (Africa, Asia, Europe, North America, South America, Oceania). Each continent's distribution is represented by a different color in the graph, allowing us to more easily understand the differences and similarities among the continents.</p>
#         <p>In the graph, some continents show a wide range of distribution for renewable energy share, while others appear to be in a narrower range. This reflects the diversity and adoption of renewable energy across different continents.</p>
#         <p>This type of analysis can help us understand how renewable energy usage is changing at the continental level and enable cross-continental comparisons. It can also provide insights into how specific continents need to shape their renewable energy strategies and policies.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-share-trend-worldwide'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share Trend Worldwide (%)</div></b>

# %%
world_data_copy = world_data.copy()  
world_data_copy['Moving_Avg'] = world_data_copy['Renewables (% equivalent primary energy)'].rolling(window=5).mean()

plt.figure(figsize=(20, 8), facecolor='whitesmoke')

plt.fill_between(world_data_copy['Year'], world_data_copy['Renewables (% equivalent primary energy)'], world_data_copy['Moving_Avg'], color='lightgray', alpha=0.4)

plt.plot(world_data_copy['Year'], world_data_copy['Renewables (% equivalent primary energy)'], label="Yearly Values", color='skyblue', alpha=0.6, linewidth=2)
plt.plot(world_data_copy['Year'], world_data_copy['Moving_Avg'], label="5-Year Moving Average", color='darkorange', linewidth=3)

plt.title('Renewable Energy Share Trend Worldwide (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')

plt.legend(fontsize=label_font_size)

plt.grid(axis='y', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the annual values and the 5-year moving average of the renewable energy share worldwide. The annual values are represented by a lighter color, while the moving average is shown in a darker shade.</p>
#         <p>The moving average helps reduce the noise in the data and presents the overall trend more clearly. In the graph, we can observe how the annual values have changed over time and how this change is reflected more smoothly in the 5-year moving average.</p>
#         <p>This type of analysis assists us in determining long-term trends and gaining an in-depth understanding of how the share of renewable energy has evolved globally. The moving average mitigates the effects of annual fluctuations and provides a more reliable basis for future policy decisions and strategies.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-share-comparison-continents'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share Comparison Among Continents (%)</div></b>

# %%
plt.figure(figsize=(20, 8), facecolor='whitesmoke')

color_palette = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown']

for continent, color in zip(continents, color_palette):
    continent_data = df_1[df_1['Entity'] == continent]
    plt.plot(continent_data['Year'], continent_data['Renewables (% equivalent primary energy)'], label=continent, color=color, linewidth=2)

plt.title('Renewable Energy Share Comparison Among Continents (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')

plt.legend(fontsize=label_font_size, loc='upper left')

plt.grid(axis='y', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates how the share of renewable energy has changed over the years in different continents (Africa, Asia, Europe, North America, South America, Oceania). The different trends and dynamics in renewable energy usage for each continent can be observed through colorful lines.</p>
#         <p>This intercontinental comparison reveals the disparities and unique trends in the utilization of renewable energy sources in each region. While some continents exhibit a steady increase in renewable energy usage, others may present a more balanced profile.</p>
#         <p>This analysis could be of critical importance in understanding intercontinental energy policies and strategies, as well as in the future development of sustainable energy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-share-developed-developing-continents'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share in Developed and Developing Continents (%)</div></b>

# %%
latest_10_years = df_1['Year'].unique()[-10:]
countries_data_last_10_years = df_1[(df_1['Year'].isin(latest_10_years)) & (~df_1['Entity'].isin(regions))]

data_last_10_years = df_1[df_1['Year'].isin(latest_10_years)]

plt.figure(figsize=(20, 8), facecolor='whitesmoke')

color_palette_last_10 = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'gray']

for continent, color in zip(continents + ['World'], color_palette_last_10):
    continent_data = data_last_10_years[data_last_10_years['Entity'] == continent]
    plt.plot(continent_data['Year'], continent_data['Renewables (% equivalent primary energy)'], label=continent, color=color, linewidth=2.5, marker='o')

plt.title('Renewable Energy Share Comparison Among Continents and World for Last 10 Years (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Year', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=label_font_size, fontweight='bold')

plt.legend(fontsize=label_font_size)

plt.grid(axis='y', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates how the share of renewable energy has changed over the past 10 years in different regions (North America, Europe, Oceania, Africa, Asia, South America) and worldwide. Each region is represented with a different color, allowing for a clear observation of the disparities between developed and developing regions.</p>
#         <p>The increasing utilization of renewable energy exhibits different dynamics in each region. While some regions show a steady increase, others may present a more balanced profile. Additionally, the overall trend worldwide is depicted in the line.</p>
#         <p>This analysis could be highly significant in designing and evaluating regional energy policies and sustainable energy development strategies. Specifically, it is a critical tool to understand the varying commitments to renewable energy sources and the changes in the utilization of these sources across different regions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='average-annual-renewable-energy-growth-rates-continent'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Average Annual Renewable Energy Growth Rates by Continent (%)</div></b>

# %%
growth_rates = {}
for continent in continents:
    continent_data = df_1[df_1['Entity'] == continent]
    growth_rate = continent_data['Renewables (% equivalent primary energy)'].pct_change().mean() * 100
    growth_rates[continent] = growth_rate

plt.figure(figsize=(20, 8), facecolor='whitesmoke')

bars = plt.bar(growth_rates.keys(), growth_rates.values(), color=['skyblue', 'lightgreen', 'lightcoral', 'orange', 'purple', 'pink'])

plt.title('Average Annual Renewable Energy Growth Rates by Continent (%)', fontsize=title_font_size, fontweight='bold')
plt.xlabel('Continent', fontsize=label_font_size, fontweight='bold')
plt.ylabel('Average Growth Rate (%)', fontsize=label_font_size, fontweight='bold')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, f'{yval:.2f}%', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

plt.grid(axis='y', linestyle='--', linewidth=0.5)

plt.subplots_adjust(top=0.95)

plt.gca().set_facecolor((0.95, 0.95, 0.95))
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the average annual growth rates of renewable energy in different regions (Africa, Asia, Europe, North America, South America, Oceania). Each region is represented with a different color, allowing for a clear visualization of the growth rate in each area.</p>
#         <p>While some regions display significant growth in renewable energy share, others exhibit lower rates. This can help us understand how the utilization of energy sources, policies, and technology is shifting across different regions. Specifically, regions with rapid growth in renewable energy could be leading in sustainable energy solutions.</p>
#         <p>This analysis serves as a valuable tool to make inter-regional comparisons, identifying which regions are leading in the renewable energy field and which ones need further development.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='fastest-growing-countries-renewable-energy-share-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 5 Fastest-Growing Countries in Renewable Energy Share (Last 10 Years)</div></b>

# %%
countries_data_last_10_years_copy = countries_data_last_10_years.copy()  
countries_data_last_10_years_copy['Yearly_Change'] = countries_data_last_10_years_copy.groupby('Entity')['Renewables (% equivalent primary energy)'].pct_change() * 100

average_growth_last_10_years = countries_data_last_10_years_copy.groupby('Entity')['Yearly_Change'].mean()
top_5_countries_growth = average_growth_last_10_years.nlargest(5)

fig, axes = plt.subplots(5, 1, figsize=(20, 18))
for i, country in enumerate(top_5_countries_growth.index):
    country_data = countries_data_last_10_years_copy[countries_data_last_10_years_copy['Entity'] == country]
    axes[i].plot(country_data['Year'], country_data['Renewables (% equivalent primary energy)'], label=country, linewidth=3)
    axes[i].set_title(f'{country} - Renewable Energy Share (%)', fontweight='bold')
    axes[i].set_xlabel('Year', fontweight='bold')
    axes[i].set_ylabel('Renewable Energy Share (%)', fontweight='bold')
    axes[i].legend(loc='upper left')
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs depict the top 5 countries showing the fastest growth in renewable energy share over the last 10 years. Each graph represents the change in renewable energy share over the years for a specific country, helping us understand which nations are leading in this field and which ones might be worth following.</p>
#         <p>Such rapid growth may be the result of specific policies, technological innovations, economic incentives, or other strategic factors. Moreover, the specific drivers and impacts in these countries can offer valuable lessons on how renewable energy can be more effectively adopted worldwide.</p>
#         <p>This analysis may be valuable for decision-makers, investors, and policymakers who want to understand what the leading countries in renewable energy are doing and apply these successes to other regions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='analysis-bottom-5-countries-renewable-energy-share-decline-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Analysis of the Bottom 5 Countries in Renewable Energy Share Decline (Last 10 Years)</div></b>

# %%
bottom_5_countries_growth = average_growth_last_10_years.nsmallest(5)
line_width = 2.5  

fig, axes = plt.subplots(5, 1, figsize=(20, 18))
for i, country in enumerate(bottom_5_countries_growth.index):
    country_data = countries_data_last_10_years[countries_data_last_10_years['Entity'] == country]
    axes[i].plot(country_data['Year'], country_data['Renewables (% equivalent primary energy)'], label=country, linewidth=line_width)  # Thicker line
    axes[i].set_title(f'{country} - Renewable Energy Share (%)', fontweight='bold')  # Bold title
    axes[i].set_xlabel('Year', fontweight='bold')  # Bold X-axis label
    axes[i].set_ylabel('Renewable Energy Share (%)', fontweight='bold')  # Bold Y-axis label
    axes[i].legend(loc='upper left')  # Legend on the left
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs display the top 5 countries experiencing the fastest decline in renewable energy share over the last 10 years. Each graph illustrates the change in renewable energy share over the years for a specific country. These declines can be a serious cause for concern and may signal potential barriers or challenges in the adoption of renewable energy.</p>
#         <p>The declines could be associated with specific economic hardships, policy changes, shifts in energy resources, or other factors. For example, reasons such as high costs, technological limitations, lack of investment, or reduced government support could lead to this drop in renewable energy share.</p>
#         <p>This analysis can aid decision-makers, investors, and policymakers in understanding and overcoming challenges in the field of renewable energy. Moreover, understanding why these countries are lagging in renewable energy can help other nations avoid similar pitfalls.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='average-renewable-energy-share-country-europe-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Average Renewable Energy Share by Country in Europe (Last 10 Years)</div></b>

# %%
european_countries = [
    'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 
    'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 
    'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'United Kingdom'
]

europe_data_last_10_years = countries_data_last_10_years[countries_data_last_10_years['Entity'].isin(european_countries)]

average_last_10_years_europe = europe_data_last_10_years.groupby('Entity')['Renewables (% equivalent primary energy)'].mean()
top_5_europe_increase = average_last_10_years_europe.nlargest(5)
top_5_europe_decrease = average_last_10_years_europe.nsmallest(5)

plt.figure(figsize=(20, 8))
bars1 = plt.bar(top_5_europe_increase.index, top_5_europe_increase.values, label='Highest Average Renewable Energy Share')
bars2 = plt.bar(top_5_europe_decrease.index, top_5_europe_decrease.values, label='Lowest Average Renewable Energy Share')
plt.title('Average Renewable Energy Share by Country in Europe (Last 10 Years)', fontsize=18, fontweight='bold')  # Bold title
plt.xlabel('Country', fontsize=14, fontweight='bold')  # Bold X-axis label
plt.ylabel('Average Renewable Energy Share (%)', fontsize=14, fontweight='bold')  # Bold Y-axis label
plt.legend()
plt.grid(True)

for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph displays the countries in Europe with the highest and lowest average renewable energy share over the last 10 years. The blue bars represent the countries with the highest average, while the orange bars represent those with the lowest average.</p>
#         <p>These differences can arise from various factors such as the countries' energy policies, technological advancements, economic conditions, and investments in renewable energy. For example, some countries may have recorded faster growth due to policies and subsidies that promote renewable energy sources.</p>
#         <p>This kind of analysis can be used to evaluate how European countries are performing in the field of renewable energy and identify best practices. It can also be used to develop strategies for increasing the renewable energy share in underperforming countries.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-usage-developing-developed-countries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage in Developing and Developed Countries</div></b>

# %%
developing_countries = ['India', 'China', 'Brazil', 'South Africa', 'Indonesia', 'Mexico', 'Philippines', 'Turkey']
developed_countries = ['United States', 'United Kingdom', 'Germany', 'France', 'Japan', 'Canada', 'Australia']

developing_data = countries_data_last_10_years[countries_data_last_10_years['Entity'].isin(developing_countries)]
developed_data = countries_data_last_10_years[countries_data_last_10_years['Entity'].isin(developed_countries)]

plt.figure(figsize=(20, 8))
plt.plot(developing_data.groupby('Year')['Renewables (% equivalent primary energy)'].mean(), label='Developing Countries', linewidth=2.5)  # Thicker line
plt.plot(developed_data.groupby('Year')['Renewables (% equivalent primary energy)'].mean(), label='Developed Countries', linewidth=2.5)  # Thicker line
plt.title('Renewable Energy Usage in Developing and Developed Countries', fontsize=18, fontweight='bold')  # Bold title
plt.xlabel('Year', fontsize=14, fontweight='bold')  # Bold X-axis label
plt.ylabel('Renewable Energy Share (%)', fontsize=14, fontweight='bold')  # Bold Y-axis label
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="container">
#     <p>This graph illustrates the changes in renewable energy usage over the last 10 years in both developing and developed countries. Significant differences in renewable energy share can be observed between developing countries (e.g., India, China, Brazil) and developed countries (e.g., the USA, Germany, Japan).</p>
#     <p><strong>Developing Countries:</strong> In these countries, investments in renewable energy may have increased in parallel with economic growth and rising energy needs. Also, goals to reduce fossil fuel dependency and environmental sustainability may have contributed to their shift towards renewable energy.</p>
#     <p><strong>Developed Countries:</strong> In developed countries, factors such as technological advancements, energy efficiency, government policies, and environmental awareness may have boosted renewable energy usage. These countries tend to have higher renewable energy standards and regulations.</p>
#     <p>This analysis can be used to evaluate the energy policies and strategies of different countries and economies. For developing countries, studies can be conducted on how renewable energy policies that have been successful in developed countries can be implemented.</p>
# </div>

# %% [markdown]
# <a id='renewable-energy-share-trend-turkey-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Share Trend in Turkey Over the Last 10 Years</div></b>

# %%
turkey_data_last_10_years = countries_data_last_10_years[countries_data_last_10_years['Entity'] == 'Turkey']

plt.figure(figsize=(20, 8))
plt.plot(turkey_data_last_10_years['Year'], turkey_data_last_10_years['Renewables (% equivalent primary energy)'], color='turquoise', linewidth=2.5, marker='o')
plt.title('Renewable Energy Share Trend in Turkey Over the Last 10 Years', fontsize=15, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Renewable Energy Share (%)', fontsize=12, fontweight='bold')
plt.grid(True)
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph depicts the renewable energy share trend in Turkey over the last 10 years. From the graph, it is apparent that there has been a general upward trend in the share of renewable energy. However, this increase appears to be irregular and not at the same rate each year.</p>
#         <p>Several factors might be influencing this irregular growth, such as policy changes related to renewable energy, technological advancements in renewable energy technologies, and economic conditions that affect energy demand and how it's met.</p>
#         <p>Moreover, the sudden rises or falls observed in certain years may be attributable to events like large investments or the commissioning of projects within a particular year.</p>
#         <p>In conclusion, the observed change in Turkey's renewable energy portfolio could be part of the country's strategies to meet its energy needs while enhancing environmental sustainability. However, to ensure a more stable and sustainable growth trend, a cohesive and integrated approach in policy, investment, and technology areas may need to be adopted.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='annual-percentage-change-renewable-energy-share-turkey-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Annual Percentage Change in Renewable Energy Share in Turkey Over the Last 10 Years</div></b>

# %%
turkey_data_last_10_years_copy = turkey_data_last_10_years.copy()
turkey_data_last_10_years_copy['Yearly_Change'] = turkey_data_last_10_years_copy['Renewables (% equivalent primary energy)'].pct_change() * 100

plt.figure(figsize=(20, 8))
plt.plot(turkey_data_last_10_years_copy['Year'], turkey_data_last_10_years_copy['Yearly_Change'], color='blue', linewidth=2.5, marker='o')
plt.title('Annual Percentage Change in Renewable Energy Share in Turkey Over the Last 10 Years', fontsize=15, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Annual Change (%)', fontsize=12, fontweight='bold')
plt.grid(True)
plt.show()

# %%
average_turkey = turkey_data_last_10_years['Renewables (% equivalent primary energy)'].mean()

global_ranking = countries_data_last_10_years.groupby('Entity')['Renewables (% equivalent primary energy)'].mean().rank(ascending=False)
turkey_rank = global_ranking['Turkey']

print(f"Turkey's average renewable energy share over the last 10 years is {average_turkey:.2f}%")
print(f"Turkey's global ranking in renewable energy share is {int(turkey_rank)}")
# Out:
# Turkey's average renewable energy share over the last 10 years is 14.71%
# Turkey's global ranking in renewable energy share is 32

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0f8ff; /* Light blue background */
#             color: #4b0082; /* Indigo text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 248, 255, 0.6); /* Slightly transparent light blue background */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the annual percentage change in the renewable energy share in Turkey over the last 10 years. The graph shows that the yearly change is quite volatile. While there are significant increases in some years, there are declines or lower increases in others.</p>
#         <p>These fluctuations may be related to changes in energy policies, commissioning of significant renewable energy projects, or economic and technological factors.</p>
#         <p>In conclusion, the graph reveals that there is no stable growth trend in Turkey's renewable energy sector; instead, there is a growth pattern that varies year by year. This can provide valuable insights into how energy strategy and practices may be shaped in the future to ensure more balanced and sustainable growth.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='average-renewable-energy-share-europe-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Average Renewable Energy Share in Europe Over the Last 10 Years</div></b>

# %%
last_10_years_data = df_1[df_1['Year'] > 2010]

european_countries = [
    'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 
    'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 
    'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'United Kingdom', 'Turkey'
]

europe_data_last_10_years = last_10_years_data[last_10_years_data['Entity'].isin(european_countries)]

average_last_10_years_europe = europe_data_last_10_years.groupby('Entity')['Renewables (% equivalent primary energy)'].mean().sort_values(ascending=False)

plt.figure(figsize=(20, 8))
bars = plt.bar(average_last_10_years_europe.index, average_last_10_years_europe.values)

bars[list(average_last_10_years_europe.index).index('Turkey')].set_color('green')

plt.title('Average Renewable Energy Share in Europe Over the Last 10 Years', fontsize=15, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Average Renewable Energy Share (%)', fontsize=12, fontweight='bold')
plt.xticks(rotation=90)
plt.axhline(y=average_last_10_years_europe['Turkey'], color='r', linestyle='--', label='Turkey')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0f8ff; /* Light blue background */
#             color: #4b0082; /* Indigo text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 248, 255, 0.6); /* Slightly transparent light blue background */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the average renewable energy share in European countries over the last 10 years. Each country is represented on the horizontal axis by its name, and the average renewable energy share is indicated on the vertical axis.</p>
#         <p>In particular, Turkey's bar is highlighted in green, and a red dashed line has been added to show Turkey's average. The graph distinctly shows where Turkey stands in Europe regarding the average renewable energy share.</p>
#         <p>This visualization can help understand the differences in renewable energy usage across different countries. It can also be used to evaluate the successes or challenges in renewable energy utilization in specific countries or regions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='average-renewable-energy-share-turkey-neighboring-countries-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Average Renewable Energy Share in Turkey and Neighboring Countries Over the Last 10 Years</div></b>

# %%
turkey_neighbors = ['Greece', 'Bulgaria', 'Georgia', 'Armenia', 'Azerbaijan', 'Iran', 'Iraq', 'Syria']

turkey_and_neighbors_data = last_10_years_data[last_10_years_data['Entity'].isin(turkey_neighbors + ['Turkey'])]

average_last_10_years_turkey_and_neighbors = turkey_and_neighbors_data.groupby('Entity')['Renewables (% equivalent primary energy)'].mean().sort_values(ascending=False)

plt.figure(figsize=(20, 8))
bars = plt.bar(average_last_10_years_turkey_and_neighbors.index, average_last_10_years_turkey_and_neighbors.values)

bars[list(average_last_10_years_turkey_and_neighbors.index).index('Turkey')].set_color('green')

plt.title('Average Renewable Energy Share in Turkey and Neighboring Countries Over the Last 10 Years', fontsize=15, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Average Renewable Energy Share (%)', fontsize=12, fontweight='bold')
plt.axhline(y=average_last_10_years_turkey_and_neighbors['Turkey'], color='r', linestyle='--', label='Turkey')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0f8ff; /* Light blue background */
#             color: #4b0082; /* Indigo text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 248, 255, 0.6); /* Slightly transparent light blue background */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the average renewable energy share in Turkey and its neighboring countries (Greece, Bulgaria, Georgia, Armenia, Azerbaijan, Iran, Iraq, Syria) over the last 10 years. Each country is represented on the horizontal axis by its name, and the average renewable energy share is indicated on the vertical axis.</p>
#         <p>In particular, Turkey's bar is highlighted in green, and a red dashed line has been added to show Turkey's average. The graph distinctly shows where Turkey stands compared to neighboring countries regarding the average renewable energy share.</p>
#         <p>This visualization can help understand the impacts of regional energy policies, levels of economic development, and technological capacities. It can also be used to evaluate Turkey's successes or challenges in renewable energy utilization.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='Conclusion-Final-Thoughts-&-Insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0f8ff; /* Light blue background */
#             color: #4b0082; /* Indigo text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 248, 255, 0.6); /* Slightly transparent light blue background */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This analysis lays out the intricate portrait of renewable energy across the globe in detail. It explores how the share of renewable energy has changed over time, the distribution among countries and regions, the leaders and laggards, continental distribution, growth dynamics, and much more.</p>
#         <p>The graphs vividly illustrate how renewable energy has grown in recent years, which countries have stood out, how it is distributed worldwide, and which continents have grown faster or lagged behind. An examination of Turkey's renewable energy profile, as well as a comparative review with Europe and neighboring countries, is also included.</p>
#         <p>The increasing role of renewable energy in the global energy portfolio is understood, with this growth not being uniform worldwide, but presenting specific trends and opportunities. This analysis offers valuable insights for policymakers, energy sector experts, and researchers looking to shape the future of sustainable energy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/02-the-evolution-of-modern-renewable-energy/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
