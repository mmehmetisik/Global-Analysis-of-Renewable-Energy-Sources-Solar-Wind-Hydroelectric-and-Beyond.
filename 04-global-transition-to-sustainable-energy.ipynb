# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 40px 20px 40px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h1 style="font-size: 32px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">Global Transition to Sustainable Energy: 1985-2022</h1>
#     <h2 style="font-size: 24px; font-weight: bold; color: #8B0000; text-align: center; font-family: 'Times New Roman'; padding: 10px;">Trends in Electricity Production from Renewable Sources</h2>
# </div>

# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 40px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h1 style="font-size: 32px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia';">Business Problem</h1>
#     <p style="font-family: 'Arial'; font-size: 18px; text-align: justify; color: #000;">
#         From 1985 to 2022, there has been a significant increase in electricity production from renewable energy sources worldwide. This dataset provides a detailed account of the progress countries have made in transitioning to renewable energy and the share of these energy sources in electricity production. Here are some business problems we can address using this dataset:
#     </p>
#     <ul style="list-style: none; padding-left: 20px;">
#         <li style="padding: 5px 0;">📈 <strong>Comparative Regional Growth:</strong> Assess which countries and regions have made significant advances in the use of renewable energy and which renewable sources have led this development. Analyze the observed increases and trends in the proportions of electricity generated from sources such as wind, hydro, and solar energy.</li>
#         <li style="padding: 5px 0;">🔍 <strong>Energy Transition Strategies:</strong> Use the increasing share of renewable energy sources in electricity production as a source of information for policy decisions, investment strategies, and future projects. Identify the regions and technologies with the highest use of renewable energy to develop strategies for managing the energy transition most effectively.</li>
#         <li style="padding: 5px 0;">🌱 <strong>Eco-Friendly Development:</strong> Understand the environmental impacts of the transition to renewable energy sources and the positive effects of this transition on ecological sustainability. This analysis is crucial in developing strategies for reducing carbon footprints and supporting sustainable development.</li>
#     </ul>
#     <p style="font-family: 'Arial'; font-size: 18px; text-align: justify; color: #000;">
#         Analyzing this dataset provides valuable insights into historical trends and guides the path towards a cleaner and more responsible energy future.
#     </p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #FFA500; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #FFA500; font-family: 'Georgia'; padding: 10px;">📊 Dataset Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         The dataset comprises 6871 observations and 4 distinct variables, representing the percentage of electricity production from renewable energy sources across various countries and regions. The data spans from 1985 to 2022, with the percentage of renewable energy observed ranging from 0% to 100%.
#     </p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Shows the name of the region or country.</li>
#         <li><strong>Code:</strong> Contains the international code for the region or country.</li>
#         <li><strong>Year:</strong> Indicates the year the data was recorded.</li>
#         <li><strong>Renewables (% electricity):</strong> Represents the percentage of electricity production from renewable energy sources.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#RenewableEnergyUsageRateinTurkeyOvertheYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;"> Renewable Energy Usage Rate in Turkey Over the Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#RenewableEnergyUsageRateOvertheYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Usage Rate Over the Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#DistributionofRenewableEnergyUsageRatefortheTop20CountriesandTurkey(Heatmap)" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Distribution of Renewable Energy Usage Rate for the Top 20 Countries and Turkey (Heatmap)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#Top5EuropeanCountriesandTurkeyRenewableEnergyUsageRates" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Top 5 European Countries and Turkey: Renewable Energy Usage Rates</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#TurkeyandNeighboringCountriesRenewableEnergyUsageRates" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Turkey and Neighboring Countries: Renewable Energy Usage Rates</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#RenewableEnergyUsageRateinTurkeyintheLast10Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Usage Rate in Turkey in the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#DistributionofRenewableEnergyUsageRateinTurkeyintheLast22Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Distribution of Renewable Energy Usage Rate in Turkey in the Last 22 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#CountrieswiththeHighestandLowestRenewableEnergyUsageRates(2022)" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Countries with the Highest and Lowest Renewable Energy Usage Rates (2022)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#TopImprovingCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Top Improving Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#LeastImprovingCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Least Improving Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#RenewableEnergyUsageBetweenDevelopedandDevelopingCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Usage Between Developed and Developing Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#RenewableEnergyUsageWorldMap" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Renewable Energy Usage World Map</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">13.</span> <a href="#ClusterAnalysisofCountriesBasedonRenewableEnergyUsage" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Cluster Analysis of Countries Based on Renewable Energy Usage</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">14.</span> <a href="#ConclusionFinalThoughts&Insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Conclusion Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import KMeans
from matplotlib.font_manager import FontProperties
from IPython.display import HTML as html_print
from termcolor import colored
from scipy import stats

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the Data Set</div></b>

# %%
df_4 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/04 share-electricity-renewables.csv")

# %%
df_4.head()
# Out:
#         Entity Code  Year  Renewables (% electricity)
# 0  Afghanistan  AFG  2000                      65.957
# 1  Afghanistan  AFG  2001                      84.746
# 2  Afghanistan  AFG  2002                      81.159
# 3  Afghanistan  AFG  2003                      67.021
# 4  Afghanistan  AFG  2004                      62.921

# %%
df_4.tail()
# Out:
#         Entity Code  Year  Renewables (% electricity)
# 6866  Zimbabwe  ZWE  2017                      58.503
# 6867  Zimbabwe  ZWE  2018                      59.412
# 6868  Zimbabwe  ZWE  2019                      55.583
# 6869  Zimbabwe  ZWE  2020                      55.132
# 6870  Zimbabwe  ZWE  2021                      54.975

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_4)
# Out:
# Shape
# (6871, 4)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_7d7e3">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d7e3_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_7d7e3_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_7d7e3_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_7d7e3_level0_col3" class="col_heading level0 col3" >Renewables (% electricity)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d7e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d7e3_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_7d7e3_row0_col1" class="data row0 col1" >AFG</td>
#       <td id="T_7d7e3_row0_col2" class="data row0 col2" >2000</td>
#       <td id="T_7d7e3_row0_col3" class="data row0 col3" >65.957440</td>
#     </tr>
#     <tr>
# ...

# %%
df_4 = df_4.drop(columns=['Code'])

# %%
df_4.head()
# Out:
#         Entity  Year  Renewables (% electricity)
# 0  Afghanistan  2000                      65.957
# 1  Afghanistan  2001                      84.746
# 2  Afghanistan  2002                      81.159
# 3  Afghanistan  2003                      67.021
# 4  Afghanistan  2004                      62.921

# %%
df_4.tail()
# Out:
#         Entity  Year  Renewables (% electricity)
# 6866  Zimbabwe  2017                      58.503
# 6867  Zimbabwe  2018                      59.412
# 6868  Zimbabwe  2019                      55.583
# 6869  Zimbabwe  2020                      55.132
# 6870  Zimbabwe  2021                      54.975

# %% [markdown]
# <a id='RenewableEnergyUsageRateinTurkeyOvertheYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage Rate in Turkey Over the Years</div></b>

# %%
turkey_data = df_4[df_4['Entity'] == 'Turkey']

fig = go.Figure(go.Scatter(
    x=turkey_data['Year'],
    y=turkey_data['Renewables (% electricity)'],
    mode='lines+markers',
    name='Renewable Energy'
))

fig.update_layout(
    title='Renewable Energy Usage Rate in Turkey Over the Years',
    xaxis_title='Year',
    yaxis_title='Renewable Energy Rate (%)',
    hovermode='x'
)

fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=5, label="Last 5 years", step="year", stepmode="backward"),
                dict(count=10, label="Last 10 years", step="year", stepmode="backward"),
                dict(count=20, label="Last 20 years", step="year", stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph displays the percentage of electricity generated from renewable sources in Turkey between 2000 and 2022. The x-axis represents the years, while the y-axis shows the percentage of renewable energy. This visualization clearly demonstrates the trends and changes in Turkey's use of renewable energy over time. Its interactive features facilitate the examination of specific time periods, making it a valuable tool for analyzing Turkey's energy policies and progress in transitioning to sustainable energy sources.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyUsageRateOvertheYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage Rate Over the Years</div></b>

# %%
fig = px.scatter(
    df_4, 
    x='Year', 
    y='Renewables (% electricity)',
    title='Renewable Energy Usage Rate Over the Years',
    labels={'Renewables (% electricity)': 'Renewable Energy Rate (%)', 'Year': 'Year'}
)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Renewable Energy Rate (%)',
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True)
)

fig.show()
# Out:
# <div>                            <div id="1c2b9062-56c9-4c27-b5e9-9f1709843428" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c2b9062-56c9-4c27-b5e9-9f1709843428")) {                    Plotly.newPlot(                        "1c2b9062-56c9-4c27-b5e9-9f1709843428",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eRenewable Energy Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This scatter plot illustrates the renewable energy usage rates over the years globally. The graph displays years on the x-axis and the percentage of electricity generated from renewable sources on the y-axis. Each point represents a country's renewable energy usage rate in a specific year. This visualization highlights global trends and changes in renewable energy usage over time. The axis titles and grid lines enhance readability and comprehension of the data. This graph is crucial for analyzing global renewable energy policies and the transition to sustainable energy sources.
#   </p>
# </div>

# %% [markdown]
# <a id='DistributionofRenewableEnergyUsageRatefortheTop20CountriesandTurkey(Heatmap)'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Usage Rate for the Top 20 Countries and Turkey (Heatmap)</div></b>

# %%
top_countries = df_4['Entity'].value_counts().head(20).index

filtered_data = df_4[df_4['Entity'].isin(top_countries)]

turkey_data = df_4[df_4['Entity'] == 'Turkey']

filtered_data_updated = filtered_data[filtered_data['Entity'] != 'European Union (27)']
filtered_data_updated = pd.concat([filtered_data_updated, turkey_data])

heatmap_data_updated = filtered_data_updated.pivot(index='Entity', columns='Year', values='Renewables (% electricity)')

plt.figure(figsize=(20, 12))
sns.heatmap(heatmap_data_updated, annot=False, cmap="viridis")
plt.title('Distribution of Renewable Energy Usage Rate for the Top 20 Countries and Turkey (Heatmap)')
plt.xlabel('Year')
plt.ylabel('Country Name')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This heatmap illustrates the distribution of renewable energy usage rates for the top 20 countries in the world and Turkey over the years. The x-axis represents the years, and the y-axis shows the names of the countries. Each cell in the heatmap reflects the percentage of electricity generated from renewable sources for that country and year, with the color intensity indicating the level of usage. The heatmap, created using the seaborn library and the 'viridis' color map, provides a clear visual representation of how renewable energy usage has evolved over time in these countries. It's particularly useful for identifying patterns, trends, and outliers in renewable energy adoption among the leading countries globally.
#   </p>
# </div>

# %% [markdown]
# <a id='Top5EuropeanCountriesandTurkeyRenewableEnergyUsageRates'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 5 European Countries and Turkey: Renewable Energy Usage Rates</div></b>

# %%
interest_countries = ['Germany', 'France', 'United Kingdom', 'Italy', 'Spain', 'Turkey']

selected_data = df_4[df_4['Entity'].isin(interest_countries)]

fig = go.Figure()

for country in interest_countries:
    country_data = selected_data[selected_data['Entity'] == country]
    fig.add_trace(go.Scatter(
        x=country_data['Year'],
        y=country_data['Renewables (% electricity)'],
        mode='lines+markers',
        name=country
    ))

fig.update_layout(
    title='Top 5 European Countries and Turkey: Renewable Energy Usage Rates',
    xaxis_title='Year',
    yaxis_title='Renewable Energy Rate (%)',
    legend_title='Countries',
    hovermode='x unified'
)

fig.show()
# Out:
# <div>                            <div id="1592180e-6653-409a-9a87-abdc6c7b8869" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1592180e-6653-409a-9a87-abdc6c7b8869")) {                    Plotly.newPlot(                        "1592180e-6653-409a-9a87-abdc6c7b8869",                        [{"mode":"lines+markers","name":"Germany","x":[1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[3.6446776,3.8522167,4.0926185,3.9537015,3.5756316,3.4929228,3.1689155,3.6971107,3.9273474,4.4629765,4.8666506,4.821224,4.2079525,4.509577,5.197814,6.1977983,6.513259,7.6431365,7.745544,9.498919,10.335665,11.512996,14.135471,1
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph compares the renewable energy usage rates of the top five European countries (Germany, France, United Kingdom, Italy, Spain) and Turkey over various years. The x-axis represents the years, while the y-axis shows the percentage of electricity generated from renewable sources. Each country's data is presented in a distinct line with markers, making it easy to track and compare their progress. The graph provides a clear visual representation of how these countries have adopted renewable energy over time, highlighting differences and similarities in their renewable energy policies. The 'hovermode' setting enhances user interaction, allowing for a detailed view of the data for each year across different countries.
#   </p>
# </div>

# %% [markdown]
# <a id='TurkeyandNeighboringCountriesRenewableEnergyUsageRates'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Turkey and Neighboring Countries: Renewable Energy Usage Rates</div></b>

# %%
grouped_data = selected_data.groupby(['Year', 'Entity'])['Renewables (% electricity)'].sum().unstack(fill_value=0)

fig = px.bar(grouped_data, 
             x=grouped_data.index, 
             y=grouped_data.columns, 
             title='Turkey and Neighboring Countries: Renewable Energy Usage Rates',
             labels={'value': 'Renewable Energy Rate (%)', 'variable': 'Country', 'index': 'Year'},
             orientation='v')

fig.update_layout(xaxis_title='Year',
                  yaxis_title='Renewable Energy Rate (%)',
                  legend_title='Country',
                  barmode='stack')
# Out:
# <div>                            <div id="c7399169-bfa3-462f-8b7f-9ebf69550a4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7399169-bfa3-462f-8b7f-9ebf69550a4c")) {                    Plotly.newPlot(                        "c7399169-bfa3-462f-8b7f-9ebf69550a4c",                        [{"alignmentgroup":"True","hovertemplate":"Entity=France\u003cbr\u003eYear=%{x}\u003cbr\u003eRenewable Energy Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":[1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This stacked bar chart displays the renewable energy usage rates for Turkey and its neighboring countries across various years. The x-axis represents the years, and the y-axis indicates the percentage of electricity generated from renewable sources. Each country's data is stacked upon one another, offering a comprehensive view of the region's collective progress in renewable energy. The chart uses distinct colors for each country, facilitating easy comparison and trend analysis. This visualization is particularly useful for understanding the dynamics of renewable energy adoption in Turkey and neighboring regions, highlighting the collective efforts and individual contributions of each country towards sustainable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyUsageRateinTurkeyintheLast10Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage Rate in Turkey in the Last 10 Years</div></b>

# %%
turkey_data = df_4[df_4['Entity'] == 'Turkey']
current_year = turkey_data['Year'].max()
last_10_years_data = turkey_data[turkey_data['Year'] > current_year - 10]

fig = px.line(last_10_years_data, 
              x='Year', 
              y='Renewables (% electricity)', 
              markers=True,
              title="Renewable Energy Usage Rate in Turkey in the Last 10 Years",
              labels={'Renewables (% electricity)': 'Renewable Energy Rate (%)', 'Year': 'Year'})

fig.update_traces(line_color='blue')
fig.update_layout(xaxis_title='Year',
                  yaxis_title='Renewable Energy Rate (%)')
# Out:
# <div>                            <div id="9358806e-89ee-4b77-80d3-71fbb0957e4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9358806e-89ee-4b77-80d3-71fbb0957e4f")) {                    Plotly.newPlot(                        "9358806e-89ee-4b77-80d3-71fbb0957e4f",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eRenewable Energy Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[27.241205,28.857298,20.912487,32.014236,32.97161,29.43022,32.176003,43.680435,42.02082,35.32963],"yaxis":"y","type":"scatter"}
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph highlights Turkey's renewable energy usage rate over the past 10 years. It features the years on the x-axis and the percentage of electricity generated from renewable sources on the y-axis. Markers are included on the graph to emphasize each year's data point. The graph's blue line visually represents the changes and trends in Turkey's renewable energy usage within this period. This visualization is particularly effective in showcasing recent shifts in Turkey's energy policy and its commitment to renewable energy, reflecting the country's efforts towards sustainability and clean energy.
#   </p>
# </div>

# %% [markdown]
# <a id='DistributionofRenewableEnergyUsageRateinTurkeyintheLast22Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Usage Rate in Turkey in the Last 22 Years</div></b>

# %%
turkey_data = df_4[df_4['Entity'] == 'Turkey']
last_22_years_data = turkey_data[turkey_data['Year'] >= 2000]

renewable_percentages = last_22_years_data['Renewables (% electricity)']

years = last_22_years_data['Year']

plt.figure(figsize=(20, 12))
plt.pie(renewable_percentages, labels=years, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Renewable Energy Usage Rate in Turkey in the Last 22 Years')
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This pie chart presents the distribution of Turkey's renewable energy usage rate from 2000 to the present. Each slice of the pie corresponds to a year, labeled directly on the chart, with the size of each slice representing the percentage of electricity generated from renewable sources in that year. The chart provides a visual representation of how Turkey's reliance on renewable energy has evolved over the last 22 years, highlighting significant years where renewable energy usage was particularly high or low. The 'autopct' feature adds percentage labels to each slice, offering a clear and precise understanding of the data. This visualization is useful for quickly grasping the overall trend in Turkey's renewable energy usage and for identifying specific years of notable change or progress.
#   </p>
# </div>

# %% [markdown]
# <a id='TopImprovingCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top Improving Countries</div></b>

# %%
df_4['Annual Change'] = df_4.groupby('Entity')['Renewables (% electricity)'].diff()

period_years = 10 
periodic_changes = df_4.groupby(['Entity', (df_4['Year'] // period_years) * period_years])['Annual Change'].sum().reset_index()

top_countries = periodic_changes.groupby('Entity')['Annual Change'].sum().sort_values(ascending=False).head(10)

top_countries.plot(kind='bar', figsize=(20, 8), title='Top Improving Countries', xlabel='Country', ylabel='Total Change Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart highlights the top 10 countries that have shown the most significant improvement in renewable energy usage rates over a 10-year period. It calculates the total change in renewable energy rates for each country by summing up the annual changes. Countries are ranked based on this total change, and the top performers are displayed on the chart. The x-axis represents the countries, while the y-axis shows the total change in renewable energy rate percentages. The chart's clear layout, with rotated labels on the x-axis for easy reading, effectively communicates which countries have made the greatest strides in increasing their use of renewable energy. This visualization is particularly useful for identifying global leaders in renewable energy progression.
#   </p>
# </div>

# %% [markdown]
# <a id='LeastImprovingCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Least Improving Countries</div></b>

# %%
df_4['Annual Change'] = df_4.groupby('Entity')['Renewables (% electricity)'].diff()

period_years = 10  
periodic_changes = df_4.groupby(['Entity', (df_4['Year'] // period_years) * period_years])['Annual Change'].sum().reset_index()

bottom_countries = periodic_changes.groupby('Entity')['Annual Change'].sum().sort_values().head(10)

bottom_countries.plot(kind='bar', figsize=(20, 6), title='Least Improving Countries', xlabel='Country', ylabel='Total Change Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart displays the 10 countries with the least improvement in renewable energy usage rates over the last decade. It quantifies the total change in each country's renewable energy rate by aggregating their annual changes. The x-axis represents the countries, and the y-axis shows their total change in renewable energy rate percentages, with lower values indicating less improvement. This visualization is instrumental in identifying countries that have made minimal progress in adopting renewable energy. The chart's layout, with clear labels and x-axis ticks rotated for better readability, effectively highlights the countries where renewable energy development has been slower or less prioritized. It serves as a crucial tool for understanding global renewable energy trends, especially in highlighting areas where efforts could be intensified.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyUsageBetweenDevelopedandDevelopingCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage Between Developed and Developing Countries</div></b>

# %%
developed_countries = ['Germany', 'France', 'United Kingdom']
developing_countries = ['Brazil', 'India', 'Turkey'] 

developed_data = df_4[df_4['Entity'].isin(developed_countries)]
developing_data = df_4[df_4['Entity'].isin(developing_countries)]

fig, axs = plt.subplots(2, 1, figsize=(20, 10), gridspec_kw={'height_ratios': [4, 1]})

for country in developed_countries:
    country_data = developed_data[developed_data['Entity'] == country]
    axs[0].plot(country_data['Year'], country_data['Renewables (% electricity)'], label=f'Developed: {country}', marker='o')

for country in developing_countries:
    country_data = developing_data[developing_data['Entity'] == country]
    axs[0].plot(country_data['Year'], country_data['Renewables (% electricity)'], label=f'Developing: {country}', marker='o')

axs[0].set_title('Renewable Energy Usage Between Developed and Developing Countries')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Renewable Energy Usage (%)')
axs[0].legend()
axs[0].grid(True)

axs[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This subplot presents a comparative analysis of renewable energy usage between developed countries (Germany, France, United Kingdom) and developing countries (Brazil, India, Turkey). The primary graph illustrates the trends in renewable energy usage percentages for these countries over the years. Each country's data is represented with a distinct line and markers, enabling a clear comparison of renewable energy adoption trends between developed and developing nations. The title, axis labels, and legend effectively guide viewers in interpreting the data. The grid enhances readability, making it easier to follow the year-wise trends. This visualization is crucial for understanding the differences in renewable energy policies and progress between developed and developing countries, highlighting the varying approaches and challenges faced by each group in the transition to sustainable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='RenewableEnergyUsageWorldMap'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Usage World Map</div></b>

# %%
renewable_data = df_4

fig = px.choropleth(
    renewable_data,
    locations="Entity",
    locationmode="country names",
    color="Renewables (% electricity)",
    animation_frame="Year",
    color_continuous_scale="YlGnBu",
    range_color=(0, 100)
)

fig.update_geos(projection_type="natural earth")

fig.update_layout(
    title="Renewable Energy Usage World Map",
    coloraxis_colorbar={"title": "Renewable Energy Usage (%)"}
)

fig.show()
# Out:
# <div>                            <div id="27cf1bf2-b20d-417a-ae78-87ea8f5efc90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27cf1bf2-b20d-417a-ae78-87ea8f5efc90")) {                    Plotly.newPlot(                        "27cf1bf2-b20d-417a-ae78-87ea8f5efc90",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Year=2000\u003cbr\u003eEntity=%{location}\u003cbr\u003eRenewables (% electricity)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Afghanistan","Africa","Africa (BP)","Africa (Ember)","Albania","Algeria","American Samoa","Angola","Antigua and Barbuda","Argentina","Armenia","Aruba","Asia","Asia (Ember)","Asia Pacific (BP)","Australia","Austria","Azerbaijan","Bahamas","B
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This animated choropleth map provides a dynamic visualization of renewable energy usage across the world. It displays the percentage of electricity generated from renewable sources in different countries, with the data animated over various years. The color intensity on the map corresponds to the renewable energy usage rate, using a 'YlGnBu' color scale that ranges from yellow (low usage) to green and blue (high usage). The animation feature allows viewers to observe changes and trends in renewable energy adoption over time. This global perspective is essential for understanding the progress and disparities in renewable energy usage worldwide. The map's natural earth projection and continuous color scale make it a compelling and informative tool for analyzing global renewable energy trends.
#   </p>
# </div>

# %% [markdown]
# <a id='ClusterAnalysisofCountriesBasedonRenewableEnergyUsage'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Cluster Analysis of Countries Based on Renewable Energy Usage</div></b>

# %%
df_cluster = df_4.groupby('Entity')['Renewables (% electricity)'].mean().reset_index()

kmeans = KMeans(n_clusters=5, n_init=10, random_state=0)

df_cluster['Cluster'] = kmeans.fit_predict(df_cluster[['Renewables (% electricity)']])

fig = px.scatter(df_cluster, x='Entity', y='Renewables (% electricity)', color='Cluster',
                 title='Cluster Analysis of Countries Based on Renewable Energy Usage',
                 labels={'Renewables (% electricity)': 'Average Renewable Energy Usage (%)'},
                 hover_data=['Entity'])

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="eae08620-1801-4a5a-8135-d14812a6d57b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eae08620-1801-4a5a-8135-d14812a6d57b")) {                    Plotly.newPlot(                        "eae08620-1801-4a5a-8135-d14812a6d57b",                        [{"hovertemplate":"Entity=%{x}\u003cbr\u003eAverage Renewable Energy Usage (%)=%{y}\u003cbr\u003eCluster=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,3,3,3,0,1,1,2,1,4,4,1,3,3,3,3,2,1,1,1,1,1,1,1,2,1,0,2,4,1,0,1,1,1,3,0,3,4,2,2,3,1,0,2,1,2,3,2,1,2,1,0,4,2,3,1,1,0,4,1,4,3,2,2,3,2,3,1,1,0,0,3,3,3,3,3,4,3,2,4,3,2,4,3,3,2,1,0,3,2,3,2,1,4,1,2,2,1,3,4,3,4,1,1,0,3,3,1,3,3,1,3,3,3,1,3,2,1,1,1,0,0,2,2,1,0,1,1,3,2,3,3,1,2,0,
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This scatter plot depicts a cluster analysis of countries based on their average renewable energy usage. The KMeans algorithm is used to group countries into five clusters, represented by different colors on the plot. The x-axis lists the countries, while the y-axis shows their average percentage of renewable energy usage. This visualization effectively categorizes countries with similar renewable energy profiles, providing insights into global patterns in renewable energy adoption. The color-coded clusters facilitate easy identification of countries with comparable renewable energy usage, making this graph a valuable tool for analyzing and comparing renewable energy strategies across different nations.
#   </p>
# </div>

# %% [markdown]
# <a id='CountrieswiththeHighestandLowestRenewableEnergyUsageRates(2022)'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Countries with the Highest and Lowest Renewable Energy Usage Rates (2022)</div></b>

# %%
df_4_data = {
    'Entity': ['Czechia', 'Malta', 'Cyprus', 'Bulgaria', 'Poland', 'Turkey', 'Luxembourg', 'Denmark', 'Austria', 'Lithuania', 'Latvia'],
    'Year': [2022] * 11,
    'Renewables (% electricity)': [12.34, 12.44, 16.7, 18.7, 20.98, 60.39, 85.71, 83.96, 76.29, 74.82, 72.13]
}
df_4 = pd.DataFrame(df_4_data)

latest_year = df_4['Year'].max()
turkey_data = df_4[df_4['Entity'] == 'Turkey']

top_5_highest = df_4.iloc[-5:]
top_5_lowest = df_4.iloc[:5]

combined_data = pd.concat([top_5_lowest, turkey_data, top_5_highest])

colors = ['red' if entity in top_5_lowest['Entity'].values 
          else ('green' if entity in turkey_data['Entity'].values else 'blue') 
          for entity in combined_data['Entity']]

plt.figure(figsize=(20, 8))
bars = plt.bar(combined_data['Entity'], combined_data['Renewables (% electricity)'], color=colors)

for bar in bars:
    height = bar.get_height()
    if bar.get_x() + bar.get_width()/2 - 0.15 < 0:
        text_x = bar.get_x() + bar.get_width()/2
    else:
        text_x = bar.get_x() + bar.get_width()/2 - 0.15
    plt.text(text_x, height + 0.5, f'{height:.2f}', ha='center', fontsize=12, fontweight='bold')

plt.title(f'Countries with the Highest and Lowest Renewable Energy Usage Rates ({latest_year})', fontsize=16, fontweight='bold')
plt.xlabel('Country', fontsize=14, fontweight='bold')
plt.ylabel('Renewable Energy Rate (%)', fontsize=14, fontweight='bold')

plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

plt.tick_params(axis='both', which='major', labelsize=12, width=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart compares the renewable energy usage rates of countries with the highest and lowest percentages, along with Turkey, for the year {latest_year}. The chart displays each country on the x-axis and their renewable energy rates on the y-axis. It provides a stark contrast between the top and bottom performers in renewable energy adoption. Including Turkey's data offers a benchmark for comparing its renewable energy efforts against these countries. The chart's design, with clear labels and a 45-degree rotation for the x-axis ticks, ensures readability. It's an effective tool for visualizing disparities in renewable energy usage across different countries and understanding where Turkey stands in relation to global leaders and laggards in renewable energy.
#   </p>
# </div>

# %% [markdown]
# <a id='ConclusionFinalThoughts&Insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1f77b4; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Conclusion: Final Thoughts & Insights</strong> This analysis provides a detailed view of the changing landscape of renewable energy usage globally, with a particular focus on Turkey. The data highlights the increasing share of renewable sources in electricity generation and their growing influence on energy policies. Turkey's progress, especially in recent years, emphasizes its commitment to enhancing renewable energy use.
#
#     The global shift towards renewable energy is crucial for environmental sustainability and energy security. Turkey's advancements in the last decade reflect its contribution to international efforts in this field. This study underlines the need for renewable energy to play a more significant role in future energy mixes and for data-driven insights to support policy and investment decisions. In conclusion, this analysis demonstrates that renewable energy is set to play a central role in both global and Turkey-specific future energy solutions.
#   </p>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/05-renewable-era-in-electricity-production/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
