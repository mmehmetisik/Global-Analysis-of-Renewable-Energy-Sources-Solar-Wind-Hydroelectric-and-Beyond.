# %% [markdown]
# <div style="border: 6px solid #4CAF50; border-radius: 10px; padding: 24px; box-shadow: 1px 1px 6px grey; background-color: #e8e8e8;">
#     <h1 style="font-size: 26px; font-weight: bold; color: #333; text-align: center; border-bottom: 2px solid #4CAF50; margin-bottom: 16px; padding-bottom: 4px;">Biofuel Production Analysis: Unveiling Trends and Forecasting Future Trajectories</h1>
#     <h2 style="font-size: 20px; color: #555; text-align: center;">Decoding the Global Shift towards Renewable Bioenergy</h2>
# </div>

# %% [markdown]
# <div style="border: 8px solid #228B22; border-radius: 12px; padding: 35px 18px; box-shadow: 2px 2px 8px grey; background-color: #f5f5f5;">
#     <h1 style="font-size: 30px; font-weight: bold; color: #2F4F4F; text-align: center; border-bottom: 3px solid #228B22; font-family: 'Calibri';">Business Problem</h1>
#     <p style="font-family: 'Georgia'; font-size: 18px; text-align: justify; color: #000;">
#         As the world pivots towards sustainable energy, biofuel emerges as a pivotal piece in the energy transition puzzle. This data-driven inquiry aims to unearth patterns and insights that can address critical business challenges:
#     </p>
#     <ul style="list-style: none; padding-left: 20px;">
#         <li style="padding: 5px 0;">🌿 <strong>Production and Consumption Dynamics:</strong> Deciphering the trends in global biofuel production and consumption across different regions.</li>
#         <li style="padding: 5px 0;">🔍 <strong>Policy Impact Analysis:</strong> Evaluating the impact of policies and incentives on the growth of the biofuel sector.</li>
#         <li style="padding: 5px 0;">💼 <strong>Investment and Growth Opportunities:</strong> Identifying potential investment opportunities by analyzing growth patterns in the biofuel industry.</li>
#     </ul>
#     <p style="font-family: 'Georgia'; font-size: 18px; text-align: justify; color: #000;">
#         Our exploration through this dataset will lay the groundwork for strategic decision-making and highlight opportunities within the biofuel landscape.
#     </p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #DAA520; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #DAA520; font-family: 'Georgia'; padding: 10px;">Dataset Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         Journeying through the rich fields of biofuel data, our dataset paints a comprehensive picture of the industry’s footprint, from burgeoning beginnings to its current status as a renewable energy staple. The dataset chronicles the surge in biofuel production, illuminating the progress made in diversifying energy sources.
#     </p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Represents the country or group, offering a panoramic view of biofuel production data across the globe.</li>
#         <li><strong>Year:</strong> Indicates the temporal dimension of the data, crucial for tracking the trajectory of biofuel production over time.</li>
#         <li><strong>Biofuels Production - TWh - Total:</strong> Quantifies the volume of biofuel production, serving as an indicator of the commitment to renewable energy.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#AnnualVolatilityinBiofuelProduction" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Annual Volatility in Biofuel Production</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#TotalBiofuelProduction" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Total Biofuel Production</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#BiofuelProductionintheUnitedStates" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Biofuel Production in the United States</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#BiofuelProductionintheUnitedStatesintheLast10Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Biofuel Production in the United States in the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#GlobalBiofuelProductionOvertheYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Global Biofuel Production Over the Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#RegionalBiofuelProductionOverTime" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Regional Biofuel Production Over Time</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#DistributionofBiofuelProductionfortheTop20CountriesandtheUnitedStatesHeatmap" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Distribution of Biofuel Production for the Top 20 Countries and the United States (Heatmap)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#TotalBiofuelProductionofSpecifiedCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Total Biofuel Production of Specified Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#UnitedStatesBiofuelProductionDistributionintheLast10Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">United States' Biofuel Production Distribution in the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#BiofuelProductionWorldMap" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Biofuel Production World Map</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#BiofuelProductionOverDifferentYearsPolarAreaChart" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Biofuel Production Over Different Years (Polar Area Chart)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#ConclusionFinalThoughts&Insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Conclusion: Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker
import plotly.express as px
import plotly.graph_objects as go
import datetime
from sklearn.cluster import KMeans
from matplotlib.font_manager import FontProperties
from IPython.display import HTML as html_print
from termcolor import colored
from scipy import stats
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the Data Set</div></b>

# %%
df_16 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/16 biofuel-production.csv")

# %%
df_16.head()
# Out:
#         Entity Code  Year  Biofuels Production - TWh - Total
# 0  Africa (BP)  NaN  1990                              0.069
# 1  Africa (BP)  NaN  1991                              0.069
# 2  Africa (BP)  NaN  1992                              0.069
# 3  Africa (BP)  NaN  1993                              0.069
# 4  Africa (BP)  NaN  1994                              0.069

# %%
df_16.tail()
# Out:
#      Entity      Code  Year  Biofuels Production - TWh - Total
# 1076  World  OWID_WRL  2017                            968.131
# 1077  World  OWID_WRL  2018                           1067.185
# 1078  World  OWID_WRL  2019                           1114.488
# 1079  World  OWID_WRL  2020                           1046.644
# 1080  World  OWID_WRL  2021                           1083.607

# %% [markdown]
# <a id='ExploratoryDataAnalysis'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_16)
# Out:
# Shape
# (1081, 4)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_c641c">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c641c_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_c641c_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_c641c_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_c641c_level0_col3" class="col_heading level0 col3" >Biofuels Production - TWh - Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c641c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c641c_row0_col0" class="data row0 col0" >Africa (BP)</td>
#       <td id="T_c641c_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_c641c_row0_col2" class="data row0 col2" >1990</td>
#       <td id="T_c641c_row0_col3" class="data row0 col3" >0.068617</td>
#     </tr>
#     <tr>
# ...

# %%
df_16 = df_16.drop(columns=['Code'])

# %%
df_16.head()
# Out:
#         Entity  Year  Biofuels Production - TWh - Total
# 0  Africa (BP)  1990                              0.069
# 1  Africa (BP)  1991                              0.069
# 2  Africa (BP)  1992                              0.069
# 3  Africa (BP)  1993                              0.069
# 4  Africa (BP)  1994                              0.069

# %% [markdown]
# <a id='AnnualVolatilityinBiofuelProduction'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Annual Volatility in Biofuel Production</div></b>

# %%
yearly_volatility = df_16.groupby('Year')['Biofuels Production - TWh - Total'].std().reset_index()

fig = go.Figure(data=[
    go.Bar(
        x=yearly_volatility['Year'],
        y=yearly_volatility['Biofuels Production - TWh - Total'],
        marker_color='orange'
    )
])

fig.update_layout(
    title='Annual Volatility in Biofuel Production',
    xaxis=dict(title='Year', tickmode='linear'),
    yaxis=dict(title='Standard Deviation of Biofuels Production (TWh)'),
    showlegend=False
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #ffa07a; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The bar chart provides a clear depiction of the fluctuations in global biofuel production over the years, as indicated by the standard deviation values. The use of orange bars helps to emphasize the variability, drawing attention to years with higher deviations. These variations suggest differing rates of biofuel production growth, which could be attributed to market conditions, policy changes, or advancements in biofuel technologies. The graph serves as an important tool for investors and policymakers to understand the stability and risk associated with the biofuel market.
#   </p>
# </div>

# %% [markdown]
# <a id='TotalBiofuelProduction'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Biofuel Production</div></b>

# %%
grouped_entities = df_16[df_16['Entity'].str.contains("World|OECD|G20|EU|America|Asia|Europe|Africa")]

group_biofuel_total = grouped_entities.groupby('Entity')['Biofuels Production - TWh - Total'].sum().sort_values(ascending=False).reset_index()

fig = px.bar(group_biofuel_total, y='Entity', x='Biofuels Production - TWh - Total', 
             title='Total Biofuel Production',
             labels={'Entity': 'Group', 'Biofuels Production - TWh - Total': 'Total Biofuels Production (TWh)'},
             color='Biofuels Production - TWh - Total', color_continuous_scale='viridis')

fig.update_layout(yaxis={'categoryorder':'total ascending'})
# Out:
# <div>                            <div id="5b7c1f12-3382-4b05-a3b3-53fde90d6c64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b7c1f12-3382-4b05-a3b3-53fde90d6c64")) {                    Plotly.newPlot(                        "5b7c1f12-3382-4b05-a3b3-53fde90d6c64",                        [{"alignmentgroup":"True","hovertemplate":"Total Biofuels Production (TWh)=%{marker.color}\u003cbr\u003eGroup=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[14871.72263,8625.900712,6245.821969,6063.09927,4751.962201,2394.27754505,2289.41936585,1632.9465183,23.887530612],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[14871.72263,8625.900712
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #8A2BE2; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar graph succinctly captures the hierarchy of biofuel production by key global entities and regions. The gradient color scale, transitioning from purple to green, visually guides the viewer through varying levels of biofuel output, highlighting the dominance of certain groups. Notably, the descending order showcases a stark disparity in production, reflecting the concentration of biofuel generation in specific areas. This visualization underlines the significance of geopolitical and economic alliances in driving biofuel production capabilities worldwide.
#   </p>
# </div>

# %% [markdown]
# <a id='BiofuelProductionintheUnitedStates'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Biofuel Production in the United States</div></b>

# %%
us_biofuel_data = df_16[df_16['Entity'] == 'United States']

frames = [go.Frame(
    data=[go.Scatter(x=us_biofuel_data['Year'][:k+1], y=us_biofuel_data['Biofuels Production - TWh - Total'][:k+1], mode='lines+markers')],
    layout=go.Layout(title_text=f'Biofuel Production in the United States ({year})')
) for k, year in enumerate(us_biofuel_data['Year'])]

initial_frame = go.Frame(
    data=[go.Scatter(x=[us_biofuel_data['Year'].iloc[0]], y=[us_biofuel_data['Biofuels Production - TWh - Total'].iloc[0]], mode='markers')],
    layout=go.Layout(title_text='Biofuel Production in the United States (First Recorded Year)')
)
frames.insert(0, initial_frame)

fig = go.Figure(
    data=[go.Scatter(x=us_biofuel_data['Year'], y=us_biofuel_data['Biofuels Production - TWh - Total'], mode='lines+markers')],
    layout=go.Layout(
        xaxis=dict(range=[us_biofuel_data['Year'].min(), us_biofuel_data['Year'].max()], autorange=False),
        yaxis=dict(range=[0, us_biofuel_data['Biofuels Production - TWh - Total'].max() + us_biofuel_data['Biofuels Production - TWh - Total'].max()*0.1], autorange=False),
        title="Biofuel Production in the United States",
        updatemenus=[dict(
            type="buttons",
            buttons=[dict(label="Play",
                          method="animate",
                          args=[None])])]
    ),
    frames=frames
)

fig.show()
# Out:
# <div>                            <div id="942d81ea-6a99-40ac-8cb5-fb844e766d20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("942d81ea-6a99-40ac-8cb5-fb844e766d20")) {                    Plotly.newPlot(                        "942d81ea-6a99-40ac-8cb5-fb844e766d20",                        [{"mode":"lines+markers","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[16.732742,19.388733,22.044724,25.833727,28.846283,30.384048,21.78628,28.832184,31.444319,32.786575,36.307648,39.801285,48.259228,63.254505,77.1594,90.5215,117.979416,162.89944,231.80676,262.64377,309.5003,345.2215,330.10876,344.545,364.5882,375.11325,399.23404,411.9172,42
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3CB371; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The animated progression of the United States' biofuel production provides an insightful narrative of growth within the sector. The rising trajectory over the years demonstrates a significant increase in biofuel output, reflecting the country's investment in renewable energy sources. The interactive aspect of the animation, with a play button feature, allows stakeholders to observe year-on-year changes, underscoring the US's strategic moves towards sustainable energy production and its role in the global energy transition.
#   </p>
# </div>

# %% [markdown]
# <a id='BiofuelProductionintheUnitedStatesintheLast10Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Biofuel Production in the United States in the Last 10 Years</div></b>

# %%
us_biofuel_data = df_16[df_16['Entity'] == 'United States']
current_year_us = us_biofuel_data['Year'].max()

last_10_years_us_biofuel = us_biofuel_data[us_biofuel_data['Year'] > current_year_us - 10]

fig_us = px.line(last_10_years_us_biofuel, 
                 x='Year', 
                 y='Biofuels Production - TWh - Total', 
                 markers=True,
                 title="Biofuel Production in the United States in the Last 10 Years",
                 labels={'Biofuels Production - TWh - Total': 'Biofuels Production (TWh)', 'Year': 'Year'})

fig_us.update_traces(line_color='green')
fig_us.update_layout(xaxis_title='Year',
                     yaxis_title='Biofuels Production (TWh)')
# Out:
# <div>                            <div id="3b689b29-f3a4-4299-a9d6-e7b41ea98f8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b689b29-f3a4-4299-a9d6-e7b41ea98f8e")) {                    Plotly.newPlot(                        "3b689b29-f3a4-4299-a9d6-e7b41ea98f8e",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eBiofuels Production (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[330.10876,344.545,364.5882,375.11325,399.23404,411.9172,424.44006,412.82147,374.58826,398.84695],"yaxis":"y","type":"scatter"
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #228B22; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The line chart reveals a decade of biofuel production trends in the United States, showcasing a pattern of growth. The use of green lines symbolizes the eco-friendly nature of biofuels. Observing the yearly data points, one can discern the impact of policy, technology, and market demand on the biofuel industry. This visualization effectively communicates the progressive steps taken towards sustainable energy over the last ten years.
#   </p>
# </div>

# %% [markdown]
# <a id='GlobalBiofuelProductionOvertheYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Biofuel Production Over the Years</div></b>

# %%
fig = px.scatter(
    df_16,
    x='Year', 
    y='Biofuels Production - TWh - Total',
    title='Global Biofuel Production Over the Years',
    labels={'Biofuels Production - TWh - Total': 'Biofuels Production (TWh)', 'Year': 'Year'}
)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Biofuels Production (TWh)',
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True)
)
# Out:
# <div>                            <div id="f721b716-ca06-4952-a097-00b3f0d50099" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f721b716-ca06-4952-a097-00b3f0d50099")) {                    Plotly.newPlot(                        "f721b716-ca06-4952-a097-00b3f0d50099",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eBiofuels Production (TWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1E90FF; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This scatter plot encapsulates global biofuel production trends, highlighting the variability and growth across different years. Each data point represents a year's production, allowing for a detailed examination of the fluctuations and trends in biofuel output. The grid lines enhance readability and precision in understanding annual production levels, underscoring the increasing importance of biofuels in the global energy mix.
#   </p>
# </div>

# %% [markdown]
# <a id='RegionalBiofuelProductionOverTime'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Regional Biofuel Production Over Time</div></b>

# %%
regional_entities = ['Germany', 'China', 'United States']

regional_yearly_biofuel = df_16[df_16['Entity'].isin(regional_entities)].pivot(index='Year', columns='Entity', values='Biofuels Production - TWh - Total')

fig = go.Figure()

for country in regional_entities:
    fig.add_trace(go.Scatter(x=regional_yearly_biofuel.index, y=regional_yearly_biofuel[country], mode='lines+markers', name=country,
                             line=dict(width=3), marker=dict(size=8)))

fig.update_layout(title={'text': "Regional Biofuel Production Over Time", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
                  xaxis_title='Year',
                  yaxis_title='Biofuels Production (TWh)',
                  legend_title='Country/Region',
                  template='plotly_dark',
                  margin=dict(l=20, r=20, t=60, b=20))
# Out:
# <div>                            <div id="a2a732a5-2dfd-4bfa-971f-d45edaa83ac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2a732a5-2dfd-4bfa-971f-d45edaa83ac1")) {                    Plotly.newPlot(                        "a2a732a5-2dfd-4bfa-971f-d45edaa83ac1",                        [{"line":{"width":3},"marker":{"size":8},"mode":"lines+markers","name":"Germany","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.0,0.05167209,0.05167209,0.28933114,0.36166975,0.5683348,0.9300046,1.0333371,1.3433348,2.583337,3.6166625,5.6833367,6.912907,10.579198,16.176365,26.60217,33.02326,29.390696,29.409874,36.448257,35.813656,33.56023
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #6A5ACD; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This multi-line chart traces biofuel production in Germany, China, and the United States, delineating their individual and comparative trajectories over time. The distinct lines for each country, with bold markers at data points, facilitate a clear comparative analysis, highlighting the unique biofuel production journey of each. The dark theme of the chart accentuates the data lines, making the trends easily discernible and emphasizing the growing role of biofuels in these key economies.
#   </p>
# </div>

# %% [markdown]
# <a id='DistributionofBiofuelProductionfortheTop20CountriesandtheUnitedStatesHeatmap'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Biofuel Production for the Top 20 Countries and the United States (Heatmap)</div></b>

# %%
top_countries = df_16['Entity'].value_counts().head(20).index

filtered_data = df_16[df_16['Entity'].isin(top_countries)]

us_data = df_16[df_16['Entity'] == 'United States']

filtered_data_updated = filtered_data[filtered_data['Entity'] != 'European Union']
filtered_data_updated = pd.concat([filtered_data_updated, us_data])

heatmap_data_updated = filtered_data_updated.pivot_table(
    index='Entity', 
    columns='Year', 
    values='Biofuels Production - TWh - Total', 
    aggfunc='sum'
)

plt.figure(figsize=(20, 12))
sns.heatmap(heatmap_data_updated, annot=False, cmap="viridis")
plt.title('Distribution of Biofuel Production for the Top 20 Countries and the United States (Heatmap)')
plt.xlabel('Year')
plt.ylabel('Country Name')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #2E8B57; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The heatmap vividly illustrates the biofuel production landscape across the top 20 countries and the United States, offering a thermal view of production intensity over the years. Shades of green represent varying levels of biofuel output, with darker hues indicating higher production volumes. This visual representation underscores the diverse biofuel contributions by different nations, highlighting trends, surges, and potentially untapped potentials within the bioenergy sector.
#   </p>
# </div>

# %% [markdown]
# <a id='TotalBiofuelProductionofSpecifiedCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Biofuel Production of Specified Countries</div></b>

# %%
specified_countries = ["China", "United States", "India", "Japan", "Germany", "Italy", "United Kingdom", "France", "Australia", "Spain", "United States", "Brazil", "Canada", "South Korea", "Mexico", "Netherlands", "Switzerland", "Sweden", "Belgium", "Poland"]

specified_countries_data = df_16[df_16['Entity'].isin(specified_countries)]

total_biofuel_production_specified_countries = specified_countries_data.groupby('Entity')['Biofuels Production - TWh - Total'].sum().sort_values(ascending=False)

plt.figure(figsize=(20, 8))
bars = plt.bar(total_biofuel_production_specified_countries.index, total_biofuel_production_specified_countries.values, color='skyblue')
plt.title('Total Biofuel Production of Specified Countries', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Biofuels Production (TWh)', fontsize=12, fontweight='bold')
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)

for bar in bars:
    if bar.get_x() + bar.get_width() / 2 == total_biofuel_production_specified_countries.index.get_loc("United States"):
        bar.set_color('red')
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom', fontsize=10)

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #1E90FF; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart showcases the total biofuel production across selected major countries, highlighting the United States with a distinct red bar to underscore its significant contribution. The visualization effectively ranks countries by their biofuel output, revealing leaders in the sector and comparative standings. Notably, the chart conveys the diverse commitment to biofuel production, serving as a benchmark for assessing global bioenergy priorities and investments.
#   </p>
# </div>

# %% [markdown]
# <a id='UnitedStatesBiofuelProductionDistributionintheLast10Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>United States' Biofuel Production Distribution in the Last 10 Years</div></b>

# %%
last_10_years_biofuel_data = df_16[(df_16['Entity'] == 'United States') & (df_16['Year'] >= 2014)]

biofuel_production = last_10_years_biofuel_data['Biofuels Production - TWh - Total']
years = last_10_years_biofuel_data['Year']

fig = go.Figure(data=[go.Pie(labels=years, values=biofuel_production, hole=0.1, 
                             pull=[0.1 if i == biofuel_production.idxmax() else 0 for i in biofuel_production.index])])

fig.update_traces(textinfo='percent+label')
fig.update_layout(title_text="United States' Biofuel Production Distribution in the Last 10 Years")
# Out:
# <div>                            <div id="3c41c41b-846a-4b89-a471-acd2a768a192" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c41c41b-846a-4b89-a471-acd2a768a192")) {                    Plotly.newPlot(                        "3c41c41b-846a-4b89-a471-acd2a768a192",                        [{"hole":0.1,"labels":[2014,2015,2016,2017,2018,2019,2020,2021],"pull":[0,0,0,0,0.1,0,0,0],"values":[364.5882,375.11325,399.23404,411.9172,424.44006,412.82147,374.58826,398.84695],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333333
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #FF6347; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The pie chart delineates the distribution of biofuel production in the United States over the last decade. The highlighted segment, pulled slightly outward, represents the year with the highest production, emphasizing its significance. This graphical representation not only illustrates annual production shares but also underscores the fluctuating nature of biofuel output, reflecting factors such as policy shifts, market demand, and technological advancements in the bioenergy sector.
#   </p>
# </div>

# %% [markdown]
# <a id='BiofuelProductionWorldMap'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Biofuel Production World Map</div></b>

# %%
fig = px.choropleth(
    df_16,
    locations="Entity",
    locationmode="country names",
    color="Biofuels Production - TWh - Total",
    animation_frame="Year",
    color_continuous_scale="YlGnBu",
    range_color=(0, df_16["Biofuels Production - TWh - Total"].max())
)

fig.update_geos(projection_type="natural earth")

fig.update_layout(
    title="Biofuel Production World Map",
    coloraxis_colorbar={"title": "Biofuel Production (TWh)"}
)
# Out:
# <div>                            <div id="16cb983f-1127-4deb-ae17-ac9c00f1e847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16cb983f-1127-4deb-ae17-ac9c00f1e847")) {                    Plotly.newPlot(                        "16cb983f-1127-4deb-ae17-ac9c00f1e847",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Year=1990\u003cbr\u003eEntity=%{location}\u003cbr\u003eBiofuels Production - TWh - Total=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Africa (BP)","Argentina","Australia","Austria","Belgium","Brazil","Canada","China","Colombia","Europe (BP)","European Union (27)","Finland","France","Germany","India","Indonesia","Italy","Mexico","Netherlands","Non-OECD (BP)","North 
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #20B2AA; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The animated choropleth map offers a global perspective on biofuel production, with each frame representing a year's data. The color gradient from light to dark blue illustrates the range of production volumes, allowing for an intuitive understanding of regional contributions to the biofuel market. This visual tool effectively communicates the growth and spread of biofuel production across countries, highlighting the increasing role of sustainable energy sources worldwide.
#   </p>
# </div>

# %% [markdown]
# <a id='BiofuelProductionOverDifferentYearsPolarAreaChart'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Biofuel Production Over Different Years (Polar Area Chart)</div></b>

# %%
df_16_polar_area = df_16.groupby('Year')['Biofuels Production - TWh - Total'].mean().reset_index()

df_16_polar_area['Year'] = df_16_polar_area['Year'].astype('category')

num_vars_polar = df_16_polar_area['Year'].nunique()

angles_polar = np.linspace(0, 2 * np.pi, num_vars_polar, endpoint=False).tolist()

stats_polar = df_16_polar_area['Biofuels Production - TWh - Total'].tolist()

stats_polar += stats_polar[:1]
angles_polar += angles_polar[:1]

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
ax.fill(angles_polar, stats_polar, color='skyblue', alpha=0.25)
ax.plot(angles_polar, stats_polar, color='blue', linewidth=2) 

ax.set_xticks(angles_polar[:-1])
ax.set_xticklabels(df_16_polar_area['Year'])

plt.title('Biofuel Production Over Different Years (Polar Area Chart)', size=16, color='black', y=1.1)

plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #4169E1; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The polar area chart elegantly displays the annual mean biofuel production, providing a 360-degree view of the data over various years. The shades of blue and the radial spread of the data points encapsulate the fluctuations and trends in biofuel production. This visualization method offers a unique perspective, highlighting the cyclical nature and potential seasonality in biofuel output, while also emphasizing years of significant production through the broader spans of the chart.
#   </p>
# </div>

# %% [markdown]
# <a id='ConclusionFinalThoughts&Insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <div style="background-color: #fafafa; border: 2px solid #20B2AA; padding: 15px; margin-top: 10px; border-radius: 10px;">
#     <h2 style="color: #20B2AA; font-family: 'Lucida Sans Unicode', sans-serif; font-size: 18px; font-weight: bold; text-align: center;">Conclusion: The Biofuel Era & Path Forward</h2>
#     <p style="font-family: 'Lucida Sans Unicode', sans-serif; font-size: 14px; color: #333; text-align: justify;">
#         Delving into the biofuel production dataset reveals the unfolding story of bioenergy as a pivotal element in the renewable energy matrix. The data chronicles a journey of progress, highlighting the pivotal role of biofuels in enhancing energy diversity and sustainability. The evident growth in biofuel production across various regions mirrors the global stride towards reducing dependency on fossil fuels and mitigating the impacts of climate change.
#     </p>
#     <p style="font-family: 'Lucida Sans Unicode', sans-serif; font-size: 14px; color: #333; text-align: justify;">
#         This analytical voyage extends beyond numbers, portraying a collective endeavor to foster a sustainable energy transition. The insights gained emphasize the importance of supportive policies, innovation in biofuel technology, and cross-border collaborations. Standing at the forefront of the bioenergy movement, this dataset not only encapsulates historical trends but also projects a future where biofuels hold a significant place in the global quest for clean and renewable energy sources, urging all stakeholders to further explore and invest in the potential of biofuels for a sustainable world.
#     </p>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/17-geothermal-energy-s-expanding-horizon/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
