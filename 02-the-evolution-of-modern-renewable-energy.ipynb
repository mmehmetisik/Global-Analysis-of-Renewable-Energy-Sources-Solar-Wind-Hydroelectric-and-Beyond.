# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 40px 20px 40px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h1 style="font-size: 32px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">The Evolution of Modern Renewable Energy</h1>
#     <h2 style="font-size: 24px; font-weight: bold; color: #8B0000; text-align: center; font-family: 'Times New Roman'; padding: 10px;">A Comprehensive Overview of Solar, Wind, Hydro, and Geo-Biomass Generation by Region</h2>
# </div>

# %% [markdown]
# <div style="border: 10px solid #4A148C; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #006400; text-align: center; border-bottom: 4px ridge #FFC107; font-family: 'Georgia'; padding: 10px;">🌍 Business Problem</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;"><strong>Modern renewable energy</strong> plays a significant role globally in building a <strong>sustainable future</strong>. Understanding how the use of renewable energy sources like solar, wind, hydro, and geo-biomass has changed in various regions from <strong>1971 to the present day</strong> is of vital importance to policymakers, energy companies, and investors.</p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li>📊 <strong>Regional and Temporal Analyses:</strong> Determine which regions have made the fastest transition to renewable energy, identify the most effective strategies, and understand where future investments need to be directed.</li>
#         <li>🎯 <strong>Sustainable Energy Goals:</strong> This analysis can be an essential step in achieving goals and can assist in optimizing energy costs.</li>
#         <li>🌱 <strong>Environmental Impact:</strong> Contribute to developing strategies to reduce impact, moving towards a greener planet.</li>
#     </ul>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">The insights derived from this dataset not only shed light on past trends but also help forge the path towards a cleaner and more responsible energy future.</p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #FFA500; border-radius: 15px; padding: 20px 20px 20px 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #FFA500; font-family: 'Georgia'; padding: 10px;">📊 Dataset Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">The dataset contains a total of <strong>5610 observations</strong> and <strong>7 variables</strong>.</p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Indicates the region name. There are a total of 104 different regions (e.g., "Africa").</li>
#         <li><strong>Code:</strong> Contains region codes. Some values may be missing, and there are a total of 81 different codes.</li>
#         <li><strong>Year:</strong> Shows the analyzed year, ranging from 1965 to 2021.</li>
#         <li><strong>Geo Biomass Other - TWh:</strong> Represents the consumption of geo-biomass and other renewable energy sources. Values range from 0 to 762.78 TWh.</li>
#         <li><strong>Solar Generation - TWh:</strong> Represents solar energy generation. Values range from 0 to 1032.50 TWh.</li>
#         <li><strong>Wind Generation - TWh:</strong> Represents wind energy generation. Values range from 0 to 1861.94 TWh.</li>
#         <li><strong>Hydro Generation - TWh:</strong> Represents hydroelectric energy generation. Values range from 0 to 4345.99 TWh.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#top-5-solar-energy-producing-countries-in-2021-an-analysis-of-the-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌞 Top 5 Solar Energy Producing Countries in 2021 An Analysis of the Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#leaders-in-wind-energy-production-in-2021-a-year-by-year-analysis" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌬️ Leaders in Wind Energy Production in 2021 A Year-by-Year Analysis</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#leaders-in-hydroelectric-energy-production-in-2021-a-year-by-year-analysis" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">💧 Leaders in Hydroelectric Energy Production in 2021 A Year-by-Year Analysis</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#leaders-in-geo-biomass-other-renewable-energy-production-in-2021-a-year-by-year-analysis" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🍂 Leaders in Geo-Biomass-Other Renewable Energy Production in 2021 A Year-by-Year Analysis</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#total-renewable-energy-generation-by-year-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">📊 Total Renewable Energy Generation by Year (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#top-10-countriesregions-by-total-renewable-energy-generation-in-2021-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌏 Top 10 Countries/Regions by Total Renewable Energy Generation in 2021 (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#renewable-energy-distribution-by-regions-in-2021-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌐 Renewable Energy Distribution by Regions in 2021 (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#top-and-bottom-5-countries-in-renewable-energy-production-in-2021-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">📈 Top and Bottom 5 Countries in Renewable Energy Production in 2021 (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#distribution-of-solar-wind-hydro-and-geobiomassother-energy-generation-1971-2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🔄 Distribution of Solar, Wind, Hydro, and Geo/Biomass/Other Energy Generation (1971-2021)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#distribution-of-energy-types-by-regions-in-2021-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🗺️ Distribution of Energy Types by Regions in 2021 (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#global-hydro-energy-generation-by-year-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌊 Global Hydro Energy Generation by Year (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#global-solar-energy-generation-by-year-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">☀️ Global Solar Energy Generation by Year (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">13.</span> <a href="#global-wind-energy-generation-by-year-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌪️ Global Wind Energy Generation by Year (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">14.</span> <a href="#global-geo-biomass-other-energy-generation-by-year-twh" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌱 Global Geo-Biomass-Other Energy Generation by Year (TWh)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">15.</span> <a href="#global-distribution-of-renewable-energy-types-in-2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌍 Global Distribution of Renewable Energy Types in 2021</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">16.</span> <a href="#global-distribution-of-renewable-energy-types-1971-2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🗓️ Global Distribution of Renewable Energy Types (1971-2021)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">17.</span> <a href="#top-10-regionscountries-in-total-renewable-energy-production" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🔝 Top 10 Regions/Countries in Total Renewable Energy Production</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">18.</span> <a href="#distribution-of-renewable-energy-types-in-top-10-regionscountries-by-year" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">📉 Distribution of Renewable Energy Types in Top 10 Regions/Countries (By Year)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">19.</span> <a href="#renewable-energy-production-in-turkey" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🇹🇷 Renewable Energy Production in Turkey</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">20.</span> <a href="#distribution-of-renewable-energy-types-in-turkey-2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🔗 Distribution of Renewable Energy Types in Turkey (2021)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">21.</span> <a href="#distribution-of-renewable-energy-types-in-turkey-all-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🔗 Distribution of Renewable Energy Types in Turkey (1971-2021)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">22.</span> <a href="#renewable-energy-production-in-turkey-last-10-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">📆 Renewable Energy Production in Turkey (Last 10 Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">23.</span> <a href="#distribution-of-renewable-energy-types-in-turkey-and-neighboring-countries-all-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🌍 Distribution of Renewable Energy Types in Turkey and Neighboring Countries (All Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">24.</span> <a href="#distribution-of-renewable-energy-types-in-turkey-and-european-countries-all-years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">🇪🇺 Distribution of Renewable Energy Types in Turkey and European Countries (All Years)</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">25.</span> <a href="#conclusion-final-thoughts--insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">💡 Conclusion Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
from IPython.display import HTML as html_print
from termcolor import colored
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the data Set</div></b>

# %%
df_2 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/02 modern-renewable-energy-consumption.csv")

# %%
df_2['Total Renewable Energy Generation - TWh'] = df_2['Solar Generation - TWh'] + df_2['Wind Generation - TWh'] + df_2['Hydro Generation - TWh'] + df_2['Geo Biomass Other - TWh']

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
df_2.head()
# Out:
#    Entity Code  Year  Geo Biomass Other - TWh  Solar Generation - TWh  \
# 0  Africa  NaN  1971                    0.164                   0.000
# 1  Africa  NaN  1972                    0.165                   0.000
# 2  Africa  NaN  1973                    0.170                   0.000
# 3  Africa  NaN  1974                    0.175                   0.000
# 4  Africa  NaN  1975                    0.172                   0.000
#
#    Wind Generation - TWh  Hydro Generation - TWh  \
# 0                  0.000                  26.013
# 1                  0.000                  29.633
# 2                  0.000                  31.346
# 3                  0.000                  35.667
# 4                  0.000                  37.718
#
#    Total Renewable Energy Generation - TWh
# 0                                   26.177
# 1                                   29.798
# 2                                   31.516
# 3                                   35.842
# ...

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_2)
# Out:
# Shape
# (5610, 8)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_3c0e0">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c0e0_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_3c0e0_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_3c0e0_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_3c0e0_level0_col3" class="col_heading level0 col3" >Geo Biomass Other - TWh</th>
#       <th id="T_3c0e0_level0_col4" class="col_heading level0 col4" >Solar Generation - TWh</th>
#       <th id="T_3c0e0_level0_col5" class="col_heading level0 col5" >Wind Generation - TWh</th>
#       <th id="T_3c0e0_level0_col6" class="col_heading level0 col6" >Hydro Generation - TWh</th>
#       <th id="T_3c0e0_level0_col7" class="col_heading level0 col7" >Total Renewable Energy Generation - TWh</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <a id='top-5-solar-energy-producing-countries-in-2021-an-analysis-of-the-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 5 Solar Energy Producing Countries in 2021 An Analysis of the Last 10 Years</div></b>

# %%
last_10_years_start = 2021 - 10

top_solar_countries_last_10_years = df_2[df_2['Year'] == 2021].nlargest(5, 'Solar Generation - TWh')

for country in top_solar_countries_last_10_years['Entity']:
    country_data_last_10_years = df_2[(df_2['Entity'] == country) & (df_2['Year'] >= last_10_years_start)]
    plt.figure(figsize=(20, 8))
    plt.plot(country_data_last_10_years['Year'], country_data_last_10_years['Solar Generation - TWh'], linewidth=3) 
    plt.title(f'Solar Energy Generation in {country} (Last 10 Years) (TWh)', fontsize=18) 
    plt.xlabel('Year', fontsize=14) 
    plt.ylabel('Solar Generation (TWh)', fontsize=14) 
    plt.grid(True)
    plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs display the solar energy generation in terawatt-hours (TWh) of the top 5 countries in terms of solar energy production over the last 10 years (2012-2021). The trend lines clearly show the increase in solar energy production in these leading countries, reflecting ongoing investments in solar technology and global efforts towards sustainable energy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='leaders-in-wind-energy-production-in-2021-a-year-by-year-analysis'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Leaders in Wind Energy Production in 2021 A Year-by-Year Analysis</div></b>

# %%
top_wind_countries = df_2[df_2['Year'] == 2021].nlargest(5, 'Wind Generation - TWh')

for country in top_wind_countries['Entity']:
    country_data = df_2[df_2['Entity'] == country]
    ax = country_data.plot(x='Year', y='Wind Generation - TWh', figsize=(20, 8), linewidth=3) 
    ax.set_title(f'Wind Energy Generation in {country} (TWh)', fontsize=18, fontweight='bold')
    ax.set_xlabel('Year', fontsize=14, fontweight='bold')
    ax.set_ylabel('Wind Generation (TWh)', fontsize=14, fontweight='bold')
    plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs depict the wind energy generation of the top 5 countries producing the most wind energy in 2021, across different years. Individual graphs are drawn for each country, allowing us to clearly see a specific country's performance over time. From the graphs, it is evident that wind energy has rapidly increased in some countries, especially in the past few years. This signifies that wind energy is occupying an increasingly important place in the renewable energy portfolio worldwide.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='leaders-in-hydroelectric-energy-production-in-2021-a-year-by-year-analysis'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Leaders in Hydroelectric Energy Production in 2021 A Year-by-Year Analysis</div></b>

# %%
top_hydro_countries = df_2[df_2['Year'] == 2021].nlargest(5, 'Hydro Generation - TWh')

for country in top_hydro_countries['Entity']:
    country_data = df_2[df_2['Entity'] == country]
    ax = country_data.plot(x='Year', y='Hydro Generation - TWh', figsize=(20, 8), linewidth=3) 
    ax.set_title(f'Hydro Energy Generation in {country} (TWh)', fontsize=18, fontweight='bold') 
    ax.set_xlabel('Year', fontsize=14, fontweight='bold') 
    ax.set_ylabel('Hydro Generation (TWh)', fontsize=14, fontweight='bold') 
    plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs illustrate the hydroelectric energy generation of the top 5 countries producing the most hydroelectric energy in 2021, over the years. Hydroelectric energy utilizes the kinetic energy of water to produce electrical energy, often obtained through large dams and river facilities. The graphs demonstrate that this type of energy has either steadily increased or remained stable in specific countries. This indicates that hydroelectric energy maintains its significance in the energy portfolio and can be a primary energy source in certain regions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='leaders-in-geo-biomass-other-renewable-energy-production-in-2021-a-year-by-year-analysis'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Leaders in Geo-Biomass-Other Renewable Energy Production in 2021 A Year-by-Year Analysis</div></b>

# %%
top_geo_biomass_other_countries = df_2[df_2['Year'] == 2021].nlargest(5, 'Geo Biomass Other - TWh')

for country in top_geo_biomass_other_countries['Entity']:
    country_data = df_2[df_2['Entity'] == country]
    ax = country_data.plot(x='Year', y='Geo Biomass Other - TWh', figsize=(20, 8), linewidth=3) 
    ax.set_title(f'Geo-Biomass-Other Energy Generation in {country} (TWh)', fontsize=18, fontweight='bold') 
    ax.set_xlabel('Year', fontsize=14, fontweight='bold') 
    ax.set_ylabel('Geo-Biomass-Other Generation (TWh)', fontsize=14, fontweight='bold') 
    plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>These graphs display the production of geo-biomass and other renewable energy types in the top 5 countries generating the most energy in these categories in 2021, across different years. Geothermal energy utilizes the Earth's internal heat, while biomass produces energy through the combustion of organic material. The graphs show how these types of energy have evolved in specific countries. A rapid increase can be observed in some countries, indicating growing interest and investment in these energy types.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='total-renewable-energy-generation-by-year-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Renewable Energy Generation by Year (TWh)</div></b>

# %%
total_energy_by_year = df_2.groupby('Year').sum(numeric_only=True)

ax = total_energy_by_year.plot(y='Total Renewable Energy Generation - TWh', figsize=(20, 8), linewidth=3, title='Total Renewable Energy Generation by Year (TWh)')
ax.set_title('Total Renewable Energy Generation by Year (TWh)', fontsize=18, fontweight='bold')
ax.set_xlabel('Year', fontsize=14, fontweight='bold')
ax.set_ylabel('Total Renewable Energy Generation - TWh', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph illustrates the total renewable energy production over the years. The graph reveals a significant increase in renewable energy production in recent years. This signifies that renewable energy is gaining increasing importance worldwide. The rise in renewable energy aligns with global efforts to combat climate change and create a sustainable future.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='top-10-countriesregions-by-total-renewable-energy-generation-in-2021-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 10 Countries/Regions by Total Renewable Energy Generation in 2021 (TWh)</div></b>

# %%
df_2['Total Renewable Energy Generation - TWh'] = df_2['Geo Biomass Other - TWh'] + df_2['Solar Generation - TWh'] + df_2['Wind Generation - TWh'] + df_2['Hydro Generation - TWh']

top_total_energy_countries_2021 = df_2[df_2['Year'] == 2021].nlargest(10, 'Total Renewable Energy Generation - TWh')

color_list = ['#4CAF50', '#8BC34A', '#CDDC39', '#FFEB3B', '#FFC107', '#FF9800', '#FF5722', '#F44336', '#E91E63', '#9C27B0']

title_font = {'fontname':'Arial', 'size':'20', 'color':'white', 'weight':'bold'}
axis_font = {'fontname':'Arial', 'size':'16', 'color':'white', 'weight':'bold'}

fig, ax = plt.subplots(figsize=(20, 8))
ax.set_facecolor('black')
fig.patch.set_facecolor('black')

bars = ax.barh(top_total_energy_countries_2021['Entity'], 
               top_total_energy_countries_2021['Total Renewable Energy Generation - TWh'], 
               color=color_list, edgecolor='black')

for bar in bars:
    bar.set_edgecolor("black")
    bar.set_linewidth(0.5)
    bar.set_alpha(0.8)

for bar in bars:
    width = bar.get_width()
    ax.annotate(f'{width:.2f}', 
                xy=(width + 10, bar.get_y() + bar.get_height() / 2),
                ha='center', va='center',
                color='white', fontsize=14, fontweight='bold')

ax.set_title('Top 10 Countries by Total Renewable Energy Generation in 2021 (TWh)', **title_font)
ax.set_xlabel('Total Renewable Energy Generation - TWh', **axis_font)
ax.set_ylabel('Country', **axis_font)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph showcases the top 10 countries by total renewable energy production in 2021. Renewable energy is derived from natural resources such as solar, wind, water, and biomass, providing a sustainable energy source without harming the environment. The graph illustrates that a significant portion of global renewable energy production is provided by these countries. This reveals the investments and leadership these countries have made in sustainable energy production.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-distribution-by-regions-in-2021-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Distribution by Regions in 2021 (TWh)</div></b>

# %%
regions_2021 = df_2[df_2['Year'] == 2021].groupby('Entity').sum(numeric_only=True)
regions_2021_sorted = regions_2021['Total Renewable Energy Generation - TWh'].sort_values(ascending=False)

oceania_idx = regions_2021_sorted.index.get_loc('Oceania')
regions_2021_limited = regions_2021_sorted.iloc[:oceania_idx + 1]

gradient_colors = sns.color_palette("viridis", len(regions_2021_limited))
highlighted_color = '#FF5733'  
colors_highlighted = [highlighted_color if region == 'Turkey' else color for region, color in zip(regions_2021_limited.index, gradient_colors)]

fig, ax = plt.subplots(figsize=(20, 8))
ax.set_facecolor('black')
fig.patch.set_facecolor('black')

bars = ax.bar(regions_2021_limited.index, 
              regions_2021_limited.values, 
              color=colors_highlighted, edgecolor='black', alpha=0.8)

for bar in bars:
    bar.set_edgecolor("black")
    bar.set_linewidth(0.5)

for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', 
                xy=(bar.get_x() + bar.get_width() / 2, height + 5),
                ha='center', va='center',
                color='white', fontsize=9, fontweight='bold')

ax.set_title('Renewable Energy Distribution by Regions in 2021 (TWh)', **title_font)
ax.set_ylabel('Total Renewable Energy Generation - TWh', **axis_font)
ax.set_xlabel('Region', **axis_font)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white', rotation=90)
ax.tick_params(axis='y', colors='white')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This bar graph illustrates the distribution of renewable energy by regions in 2021. Each bar represents the total renewable energy in terawatt-hours (TWh) in a specific region. The graph uncovers a notably uneven distribution of renewable energy production worldwide. While some regions host intense renewable energy production, others exhibit significantly lower rates. This discrepancy highlights that factors such as the utilization of renewable energy resources, the spread rate of technology, policy, and economic structure may vary across regions, leading to this imbalanced production landscape.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='top-and-bottom-5-countries-in-renewable-energy-production-in-2021-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top and Bottom 5 Countries in Renewable Energy Production in 2021 (TWh)</div></b>

# %%
df_2['Total Renewable Energy Generation - TWh'] = df_2['Geo Biomass Other - TWh'] + df_2['Solar Generation - TWh'] + df_2['Wind Generation - TWh'] + df_2['Hydro Generation - TWh']
top_5_total_energy_countries_2021 = df_2[df_2['Year'] == 2021].nlargest(5, 'Total Renewable Energy Generation - TWh')
bottom_5_total_energy_countries_2021 = df_2[df_2['Year'] == 2021].nsmallest(5, 'Total Renewable Energy Generation - TWh')
combined_top_bottom_countries = pd.concat([top_5_total_energy_countries_2021, bottom_5_total_energy_countries_2021])
colors = ['green' if i < 5 else 'red' for i in range(10)]

fig, ax = plt.subplots(figsize=(16, 10))

bars = ax.bar(combined_top_bottom_countries['Entity'], combined_top_bottom_countries['Total Renewable Energy Generation - TWh'], color=colors)

ax.set_title('Top and Bottom 5 Entities in Renewable Energy Production in 2021 (TWh)', fontsize=18, fontweight='bold')
ax.set_ylabel('Total Renewable Energy Generation - TWh', fontsize=14, fontweight='bold')
ax.set_xlabel('Entity', fontsize=14, fontweight='bold')

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 50, round(yval, 2), ha='center', va='bottom', fontsize=10)

ax.set_facecolor('white')
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This bar graph showcases the top 5 and bottom 5 countries in total renewable energy production in 2021. The graph reveals a significant disparity between the leading countries in renewable energy production and those that are less advanced in this field. This visualization assists in understanding which countries are at the forefront of renewable energy production and which ones are underperforming. The leading countries may have advantages in factors such as technology, infrastructure, investment, and policy. On the other hand, the countries at the bottom may not fully utilize their renewable energy potential or lack sufficient investment and policies in this area.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-solar-wind-hydro-and-geobiomassother-energy-generation-1971-2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Solar, Wind, Hydro, and Geo/Biomass/Other Energy Generation (1971-2021)</div></b>

# %%
solar_wind_hydro_geo_biomass_distribution = df_2.groupby('Year').sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]

plt.figure(figsize=(20, 8))
plt.stackplot(solar_wind_hydro_geo_biomass_distribution.index, 
              solar_wind_hydro_geo_biomass_distribution['Solar Generation - TWh'], 
              solar_wind_hydro_geo_biomass_distribution['Wind Generation - TWh'], 
              solar_wind_hydro_geo_biomass_distribution['Hydro Generation - TWh'],
              solar_wind_hydro_geo_biomass_distribution['Geo Biomass Other - TWh'], 
              labels=['Solar', 'Wind', 'Hydro', 'Geo/Biomass/Other'], 
              colors=['yellow', 'blue', 'green', 'brown'], 
              alpha=0.6)
plt.title('Distribution of Solar, Wind, Hydro, and Geo/Biomass/Other Energy Generation (1971-2021)', fontsize=15, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Energy Generation (TWh)', fontsize=12, fontweight='bold')
plt.legend(loc='upper left', fontsize=12)
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This stacked area graph illustrates the distribution of Solar, Wind, Hydroelectric, and Geothermal/Biomass/Other energy production from 1971 to 2021. Each colored area represents the production of a specific type of energy over time, showcasing the following:</p>
#         <p><strong>Solar Energy (Yellow):</strong> The yellow area at the bottom of the graph represents solar energy production over time. It often shows an increase in recent years, as solar energy technology becomes more prevalent with advancements.</p>
#         <p><strong>Wind Energy (Blue):</strong> Wind energy production is showing a noticeable increase over the years. This can be associated with the rise in the installation of wind turbines and wind energy becoming a popular renewable energy source.</p>
#         <p><strong>Hydroelectric Energy (Green):</strong> Hydroelectric energy is one of the oldest forms of renewable energy and typically shows a stable production profile. Large dams and water power can constitute a significant portion of energy production.</p>
#         <p><strong>Geothermal/Biomass/Other (Brown):</strong> This category encompasses geothermal energy, biomass, and other renewable energy types. While these energy types might make up a smaller share of total energy production, they can be significant in specific regions or applications.</p>
#         <p>Looking at the graph as a whole, we can see that the total production of renewable energy types has increased over time. This can be associated with renewable energy sources becoming increasingly important worldwide. Renewable energy plays a key role in combating climate change, and this graph allows us to observe how different renewable energy types come together and change over time. It highlights the shift towards cleaner energy sources and provides insights into the energy landscape, reflecting global efforts to reduce reliance on fossil fuels and embrace sustainable energy solutions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-energy-types-by-regions-in-2021-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Energy Types by Regions in 2021 (TWh)</div></b>

# %%
regions_2021 = df_2[df_2['Year'] == 2021].groupby('Entity').sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]
regions_2021['Total Energy Generation - TWh'] = regions_2021.sum(axis=1)
regions_2021_sorted_31 = regions_2021.sort_values(by='Total Energy Generation - TWh', ascending=False).head(31)
regions_2021_sorted_31 = regions_2021_sorted_31.drop(columns='Total Energy Generation - TWh')

fig, ax = plt.subplots(figsize=(20, 8))
regions_2021_sorted_31.plot(kind='bar', stacked=True, ax=ax, width=0.7, color=sns.color_palette("tab10", 4))
ax.set_title('Distribution of Energy Types by Top 31 Regions in 2021 (TWh)', fontsize=16, fontweight='bold')
ax.set_xlabel('Region', fontsize=14, fontweight='bold')
ax.set_ylabel('Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This bar graph illustrates the distribution of different types of renewable energy production (Solar, Wind, Hydroelectric, Geothermal/Biomass/Other) by regions in 2021. Each color within a region's bar represents the production of a specific type of energy.</p>
#         <p>The graph reveals how different regions around the world are utilizing renewable energy potential and focusing on various energy types. In some regions, hydroelectric energy may be dominant, while in others, solar or wind energy may be more prevalent. This distribution varies depending on factors such as the availability of natural resources, technological advancements, investments, and policies.</p>
#         <p>Understanding this distribution can provide insights into the renewable energy landscape and the strategies adopted by different regions. It emphasizes the importance of renewable energy and reflects the diverse approaches taken to harness natural resources. The graph also highlights the need for tailored solutions based on regional characteristics to enhance renewable energy utilization and contribute to global sustainability goals.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-hydro-energy-generation-by-year-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Hydro Energy Generation by Year (TWh)</div></b>

# %%
total_hydro_energy_by_year = df_2.groupby('Year').sum(numeric_only=True)['Hydro Generation - TWh']

plt.figure(figsize=(20, 8))
plt.plot(total_hydro_energy_by_year, linewidth=3, color='blue') 
plt.title('Global Hydro Energy Generation by Year (TWh)', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Hydro Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This graph displays the global hydroelectric energy production by year. The trend line in the graph reveals a general increase in hydroelectric energy production over time.</p>
#         <p>This increase in hydroelectric energy indicates that it is recognized worldwide as a reliable and effective renewable energy source. The upward trend can be attributed to factors such as technological advancements, growth in investments, efficient utilization of water resources, and the adoption of environmentally friendly energy policies.</p>
#         <p>Understanding the global trajectory of hydroelectric energy production offers valuable insights into the role of hydro energy in the world's energy landscape. It emphasizes the enduring significance of hydroelectric power and reflects the ongoing efforts to harness water resources for sustainable energy generation. This graph serves as a testament to the potential and growth of hydroelectric energy as part of the broader movement towards renewable energy solutions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-solar-energy-generation-by-year-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Solar Energy Generation by Year (TWh)</div></b>

# %%
total_solar_energy_by_year = df_2.groupby('Year').sum(numeric_only=True)['Solar Generation - TWh']

plt.figure(figsize=(20, 8))
plt.plot(total_solar_energy_by_year, linewidth=3, color='orange')
plt.title('Global Solar Energy Generation by Year (TWh)', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Solar Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>The graph depicts the global solar energy generation by year, showing a significant increase in solar energy production in recent years. This rise may be attributed to factors such as an increase in the efficiency of solar energy, a decrease in the costs of solar panels, and a growing interest in renewable energy sources.</p>
#         <p>Solar energy, as a clean and abundant resource, has emerged as a vital component of the global energy mix. The rapid growth in solar energy production demonstrates the world's commitment to harnessing renewable energy and reducing dependence on fossil fuels.</p>
#         <p>The technological advancements that have made solar energy more accessible and affordable are also reflected in the graph, contributing to its increasing popularity. This visualization serves as an encouraging sign of the global movement towards sustainable energy solutions and the potential of solar energy to play a significant role in this transition.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-wind-energy-generation-by-year-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Wind Energy Generation by Year (TWh)</div></b>

# %%
total_wind_energy_by_year = df_2.groupby('Year').sum(numeric_only=True)['Wind Generation - TWh']

plt.figure(figsize=(20, 8))
plt.plot(total_wind_energy_by_year, linewidth=3, color='lightblue')
plt.title('Global Wind Energy Generation by Year (TWh)', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Wind Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>The graph illustrates the global wind energy generation by year, indicating a consistent increase in wind energy production over time. This upward trend can be linked to advancements in wind turbine technology, allowing wind energy to be captured more effectively.</p>
#         <p>Wind energy, being a renewable and sustainable source, has gained significant attention in the global energy landscape. The graph showcases the growing reliance on wind energy, driven by technological innovations and the global push towards cleaner energy solutions.</p>
#         <p>The rise in wind energy production highlights the potential of harnessing natural forces to meet energy demands without harming the environment. This trend signifies not only a technological triumph but also a collective movement towards a greener future. The widespread adoption of wind energy reflects the ongoing efforts to reduce greenhouse gas emissions and the impact of climate change, making wind energy an integral part of the global renewable energy portfolio.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-geo-biomass-other-energy-generation-by-year-twh'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Geo-Biomass-Other Energy Generation by Year (TWh)</div></b>

# %%
total_geo_biomass_other_energy_by_year = df_2.groupby('Year').sum(numeric_only=True)['Geo Biomass Other - TWh']

plt.figure(figsize=(20, 8))
plt.plot(total_geo_biomass_other_energy_by_year, linewidth=3, color='green')
plt.title('Global Geo-Biomass-Other Energy Generation by Year (TWh)', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Geo-Biomass-Other Energy Generation (TWh)', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>The graph depicts the global production of geothermal, biomass, and other renewable energy sources over time, highlighting a consistent increase in their generation. These types of energy add diversity to sustainable energy production and are indicative of a broader shift towards harnessing multiple renewable energy sources.</p>
#         <p>Geothermal Energy: Utilizing the Earth's internal heat, geothermal energy has become an essential part of the renewable energy mix in regions with significant geothermal activity. Biomass Energy: Biomass energy, derived from organic materials, is another area that has seen growth. Other Renewable Sources: This category might include sources like tidal energy, wave energy, etc.</p>
#         <p>The combined growth in these energy types emphasizes the global move towards diversifying renewable energy sources. This diversification ensures a more resilient energy system, reducing dependence on a single source and promoting sustainable practices.</p>
#         <p>These trends are aligned with global goals to reduce greenhouse gas emissions, combat climate change, and foster sustainable development. The graph reflects the innovation and commitment to harnessing different forms of renewable energy, making them a vital part of the energy future.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-distribution-of-renewable-energy-types-in-2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Distribution of Renewable Energy Types in 2021</div></b>

# %%
global_percentage_2021 = df_2[df_2['Year'] == 2021].sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]
global_percentage_2021 = global_percentage_2021 / global_percentage_2021.sum() * 100

plt.figure(figsize=(8, 8))
plt.pie(global_percentage_2021, labels=global_percentage_2021.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'blue', 'green', 'purple'])
plt.title('Global Distribution of Renewable Energy Types in 2021', fontsize=15, fontweight='bold')
plt.axis('equal')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>The pie chart represents the global distribution of different renewable energy types in 2021, illustrating how the renewable energy portfolio is divided among solar, wind, hydro, and geothermal/biomass/other energy sources.</p>
#         <p>Solar Energy's share indicates the success of solar power technologies, while Wind Energy's slice of the pie reflects the growing importance of wind turbines. Hydroelectric energy continues to be a dominant renewable energy source, and the Geothermal/Biomass/Other category includes various other renewable energy sources.</p>
#         <p>The pie chart provides a snapshot of the world's renewable energy landscape in 2021, highlighting how different countries and regions are investing in various renewable energy technologies. It underlines the global commitment to a sustainable future and paves the way for innovative energy solutions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='global-distribution-of-renewable-energy-types-1971-2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Distribution of Renewable Energy Types (1971-2021)</div></b>

# %%
global_percentage_all_years = df_2.sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]
global_percentage_all_years = global_percentage_all_years / global_percentage_all_years.sum() * 100

plt.figure(figsize=(8, 8))
plt.pie(global_percentage_all_years, labels=global_percentage_all_years.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'blue', 'green', 'purple'])
plt.title('Global Distribution of Renewable Energy Types (1971-2021)', fontsize=15, fontweight='bold')
plt.axis('equal')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #f0fff0; /* Light green background */
#             color: #0000ff; /* Blue text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 3px solid #4b0082; /* Slightly thick border */
#             border-radius: 15px;
#             background-color: rgba(240, 255, 240, 0.6); /* Slightly transparent light green background */
#             font-style: italic; /* Italic text */
#             word-wrap: break-word; /* Break words to next line */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This pie chart represents the global distribution of renewable energy types from 1971 to 2021. It shows how different renewable energy sources have contributed to the global energy mix over the last five decades.</p>
#         <p>Solar energy's growth in recent years and wind energy's steady development are evident. Hydroelectric energy continues to dominate, reflecting its long-standing significance. Geothermal, biomass, and other sources, though smaller, play a crucial role in diversifying energy production.</p>
#         <p>This historical perspective underscores the dynamic nature of renewable energy and the global commitment to sustainability. It provides valuable insights into the past, present, and potential future of renewable energy, emphasizing the world's shift towards cleaner and more sustainable energy solutions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='top-10-regionscountries-in-total-renewable-energy-production'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Top 10 Regions/Countries in Total Renewable Energy Production</div></b>

# %%
total_renewable_energy_by_region = df_2.groupby('Entity').sum(numeric_only=True).sum(axis=1).sort_values(ascending=False)

top_regions = total_renewable_energy_by_region.head(10)

plt.figure(figsize=(20, 8))
top_regions.plot(kind='bar', color='skyblue')
plt.title('Top 10 Regions/Countries in Total Renewable Energy Production', fontsize=15, fontweight='bold', weight='bold')
plt.xlabel('Region/Country', weight='bold')
plt.ylabel('Total Renewable Energy Production (TWh)', weight='bold')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This bar chart illustrates the top 10 regions or countries in total renewable energy production across all available years. By grouping and summing the data based on region or country, the chart helps reveal the global leaders in renewable energy.</p>
#         <p>The Asian region stands out, ahead of other significant contributors. This visualization can aid policymakers and energy enthusiasts in understanding the global landscape of renewable energy production. It emphasizes the importance of regional efforts and investments in renewable energy, reflecting the world's shift towards cleaner and more sustainable energy solutions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-renewable-energy-types-in-top-10-regionscountries-by-year'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Types in Top 10 Regions/Countries (By Year)</div></b>

# %%
renewable_energy_distribution_by_region = df_2.groupby('Entity').sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']].sort_values(by='Hydro Generation - TWh', ascending=False)

top_regions_distribution = renewable_energy_distribution_by_region.head(10)

top_regions_distribution.plot(kind='bar', stacked=True, figsize=(20, 8), colormap='viridis')
plt.title('Distribution of Renewable Energy Types in Top 10 Regions/Countries (By Year)', fontsize=15, weight='bold')
plt.xlabel('Region/Country', weight='bold')
plt.ylabel('Total Renewable Energy Production (TWh)', weight='bold')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Energy Type')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This stacked bar chart displays the distribution of different renewable energy types (solar, wind, hydroelectric, and biomass) in the top 10 regions or countries across all years. It allows us to observe the prominent role of hydroelectric energy in many regions, followed by other energy types.</p>
#         <p>Understanding this distribution is vital for energy planning and sustainability efforts. It reveals the diversified energy landscape and provides insights into how regions are utilizing their renewable energy potential. The chart emphasizes the significance of hydroelectric power and highlights the contribution of other renewable energy sources in shaping the global energy portfolio.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-production-in-turkey'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Production in Turkey</div></b>

# %%
turkey_data = df_2[df_2['Entity'] == 'Turkey']

turkey_total_renewable_by_year = turkey_data.set_index('Year').sum(numeric_only=True, axis=1)

plt.figure(figsize=(20, 8))
turkey_total_renewable_by_year.plot(kind='line', color='blue', linewidth=2.5)
plt.title('Renewable Energy Production in Turkey', fontsize=15, weight='bold')
plt.xlabel('Year', weight='bold')
plt.ylabel('Total Renewable Energy Production (TWh)', weight='bold')
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This line chart displays the trend of renewable energy production in Turkey over the years. A noticeable increase in renewable energy production can be observed, particularly in recent years.</p>
#         <p>This growth trend emphasizes Turkey's commitment to renewable energy, reflecting global efforts to reduce reliance on fossil fuels and embrace sustainable energy solutions. The chart provides valuable insights into Turkey's energy landscape and the role of renewable energy in shaping the country's energy future.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-renewable-energy-types-in-turkey-2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Types in Turkey (2021)</div></b>

# %%
turkey_data_2021 = df_2[(df_2['Entity'] == 'Turkey') & (df_2['Year'] == 2021)]

turkey_energy_distribution_2021 = turkey_data_2021[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']].sum()

plt.figure(figsize=(9, 9))
turkey_energy_distribution_2021.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['gold', 'blue', 'green', 'purple'], fontsize=12)
plt.title('Distribution of Renewable Energy Types in Turkey (2021)', fontsize=15, weight='bold')
plt.ylabel('')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>In 2021, the distribution of energy production by renewable energy sources in Turkey is as follows:</p>
#         <p>Hydroelectric energy holds the largest share with 74.1% of the total production. This indicates that Turkey heavily relies on hydroelectric energy for its renewable energy production.</p>
#         <p>Wind energy comes in second with 12.9%.</p>
#         <p>Geo Biomass energy is third with a share of 9.1%,</p>
#         <p>While solar energy holds the fourth place with 3.9%.</p>
#         <p>This distribution suggests that Turkey has significant potential in hydroelectric energy and benefits from this source more than other renewable energy sources.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-renewable-energy-types-in-turkey-all-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Types in Turkey (1971-2021)</div></b>

# %%
turkey_energy_distribution = turkey_data[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']].sum()

plt.figure(figsize=(9, 9))
turkey_energy_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['gold', 'blue', 'green', 'purple'], fontsize=12)
plt.title('Distribution of Renewable Energy Types in Turkey (1971-2021)', fontsize=15, weight='bold')
plt.ylabel('')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This pie chart visualizes the distribution of different renewable energy types in Turkey, considering data from all available years. The chart provides insights into how Turkey's renewable energy production is divided among various sources such as solar, wind, hydroelectric, and geothermal/biomass/other.</p>
#         <p>Solar Energy (Gold): The portion of the pie represented in gold indicates the contribution of solar energy to Turkey's renewable energy portfolio. It reflects the utilization of solar panels and the country's investment in capturing sunlight for energy.</p>
#         <p>Wind Energy (Blue): The blue segment shows Turkey's wind energy production, signifying the role of wind turbines in harnessing wind power for electricity generation.</p>
#         <p>Hydroelectric Energy (Green): The green portion of the pie highlights the significance of hydroelectric energy in Turkey. This includes energy generated through dams and water flow, making up a substantial part of the renewable energy mix.</p>
#         <p>Geothermal/Biomass/Other (Purple): The purple section encompasses other renewable energy types, including geothermal energy and biomass. It signifies the diversification in Turkey's renewable energy production.</p>
#         <p>The pie chart offers a comprehensive view of Turkey's renewable energy landscape, emphasizing the country's efforts to balance different renewable energy sources. It also indicates the potential for further development and investment in specific sectors, aligning with global sustainability goals and the transition toward a greener energy economy.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='renewable-energy-production-in-turkey-last-10-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Renewable Energy Production in Turkey (Last 10 Years)</div></b>

# %%
turkey_last_10_years = turkey_data[turkey_data['Year'] > (turkey_data['Year'].max() - 10)]

plt.figure(figsize=(20, 10))
for energy_type in ['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']:
    plt.plot(turkey_last_10_years['Year'], turkey_last_10_years[energy_type], label=energy_type.split(' ')[0], linewidth=3)

plt.title('Renewable Energy Production in Turkey (Last 10 Years)', fontsize=18, weight='bold')
plt.xlabel('Year', fontsize=14, weight='bold')
plt.ylabel('Energy Production (TWh)', fontsize=14, weight='bold')
plt.legend(title='Energy Type', fontsize=12, title_fontsize=14)
plt.grid(True, linestyle='--', linewidth=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This line chart illustrates renewable energy production in Turkey over the last 10 years, segregating it by different energy types (solar, wind, hydroelectric, biomass). Thick lines and labels clearly depict growth trends in each energy type, with hydroelectric energy consistently contributing significantly.</p>
#         <p>The chart provides insights into the dynamics of renewable energy sources in Turkey, reflecting the country's strategy and commitment to sustainable energy. It also highlights the potential areas of growth and underscores the importance of a diversified energy portfolio for achieving long-term energy security and environmental goals.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-renewable-energy-types-in-turkey-and-neighboring-countries-all-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Types in Turkey and Neighboring Countries (All Years)</div></b>

# %%
neighboring_countries = ['Turkey', 'Greece', 'Bulgaria', 'Georgia', 'Armenia', 'Iran', 'Iraq', 'Syria']

neighboring_data = df_2[df_2['Entity'].isin(neighboring_countries)]

neighboring_renewable_distribution = neighboring_data.groupby('Entity').sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]

neighboring_renewable_distribution_sorted = neighboring_renewable_distribution.sum(axis=1).sort_values(ascending=False).index
neighboring_renewable_distribution_sorted = neighboring_renewable_distribution.loc[neighboring_renewable_distribution_sorted]

neighboring_renewable_distribution_sorted.plot(kind='bar', stacked=True, figsize=(15, 7), colormap='viridis')
plt.title('Distribution of Renewable Energy Types in Turkey and Neighboring Countries (All Years)', fontsize=15, weight='bold')
plt.xlabel('Country/Region', fontsize=14, weight='bold')
plt.ylabel('Total Renewable Energy Production (TWh)', fontsize=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Energy Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This stacked bar chart displays the distribution of renewable energy types in Turkey and its neighboring countries, arranged in descending order by total renewable energy production. It offers a comparison that provides insights among neighboring regions, highlighting Turkey's leadership in hydroelectric energy and the overall renewable energy landscape.</p>
#         <p>The chart emphasizes the strategic importance of renewable energy sources in regional cooperation and energy security. It reflects the diverse energy profiles of the countries and underscores the need for collaboration, innovation, and investment to foster sustainable growth and align with global environmental objectives.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='distribution-of-renewable-energy-types-in-turkey-and-european-countries-all-years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Distribution of Renewable Energy Types in Turkey and European Countries (All Years)</div></b>

# %%
european_countries = ['Turkey', 'Germany', 'France', 'United Kingdom', 'Italy', 'Spain', 'Netherlands', 'Sweden', 'Poland', 'Denmark']

european_data = df_2[df_2['Entity'].isin(european_countries)]

european_renewable_distribution = european_data.groupby('Entity').sum(numeric_only=True)[['Solar Generation - TWh', 'Wind Generation - TWh', 'Hydro Generation - TWh', 'Geo Biomass Other - TWh']]

european_renewable_distribution_sorted = european_renewable_distribution.sum(axis=1).sort_values(ascending=False).index
european_renewable_distribution_sorted = european_renewable_distribution.loc[european_renewable_distribution_sorted]

european_renewable_distribution_sorted.plot(kind='bar', stacked=True, figsize=(15, 7), colormap='viridis')
plt.title('Distribution of Renewable Energy Types in Turkey and European Countries (All Years)', fontsize=15, weight='bold')
plt.xlabel('Country/Region', fontsize=14, weight='bold')
plt.ylabel('Total Renewable Energy Production (TWh)', fontsize=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Energy Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This stacked bar chart compares Turkey's renewable energy production with other significant European countries or regions, illustrating the distribution of different renewable energy types such as solar, wind, hydroelectric, and biomass across all years. Turkey's hydroelectric energy production is substantial, and this visualization helps us understand its position among other actors in Europe.</p>
#         <p>The chart provides valuable insights into the energy dynamics within Europe, reflecting the diverse energy profiles and strategies adopted by various countries. It emphasizes the growing importance of renewable energy sources and the collaborative efforts required to meet regional and global sustainability goals. Understanding these trends can inform policy decisions, investment strategies, and regional cooperation to foster a greener and more resilient energy future in Europe.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='conclusion-final-thoughts--insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: 'Verdana', sans-serif;
#             background-color: #e6f7ff; /* Light blue background */
#             color: #333333; /* Dark grey text */
#             margin: 0;
#             padding: 0;
#             overflow-x: hidden; /* Prevent horizontal scrolling */
#         }
#         .container {
#             max-width: 100%; /* Full width */
#             margin: 40px auto;
#             padding: 30px;
#             border: 2px solid #008080; /* Teal border */
#             border-radius: 15px;
#             background-color: rgba(230, 247, 255, 0.6); /* Slightly transparent light blue background */
#         }
#         p {
#             font-size: 18px;
#             line-height: 1.6;
#             margin: 20px 0;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>The analysis of renewable energy data from 1971 to 2021 provides a comprehensive view of the global landscape and Turkey's position in it. The evident growth in renewable energy sources like hydro, solar, wind, and geothermal/biomass emphasizes the global shift towards cleaner energy solutions. Turkey, with its significant hydroelectric production, demonstrates a balanced energy mix and growth potential. The comparison with European and neighboring countries showcases Turkey's commitment to sustainability and renewable energy adoption. Overall, this study underlines the importance of renewable energy in shaping a greener future and the role of data-driven insights in guiding policy and investment decisions.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/03-renewable-power-trends-1965-2022/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
