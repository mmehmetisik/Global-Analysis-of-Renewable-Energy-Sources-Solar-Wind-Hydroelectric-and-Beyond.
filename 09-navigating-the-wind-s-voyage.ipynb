# %% [markdown]
# <div style="border: 5px solid #1E90FF; border-radius: 8px; padding: 20px; box-shadow: 1px 1px 4px grey; background-color: #f0f0f0;">
#     <h1 style="font-size: 24px; font-weight: bold; color: #2F4F4F; text-align: center; border-bottom: 2px solid #4682B4; font-family: 'Arial'; padding-bottom: 10px;">Navigating the Wind's Voyage: A Decade-Wise Wind Energy Growth Analysis</h1>
#     <h2 style="font-size: 20px; color: #2F4F4F; text-align: center; font-family: 'Arial'; margin-top: 10px;">Examining the Surge of Wind Power in an Age of Renewable Transformation</h2>
# </div>

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 20px; background-color: #E8F5E9;">
#     <h2 style="color: #388E3C; font-family: 'Arial', sans-serif; font-size: 24px; font-weight: bold; text-align: center; margin-bottom: 20px;">Business Problem</h2>
#     <hr style="border-top: 3px solid #81C784;">
#     <p style="font-family: 'Arial', sans-serif; font-size: 16px; color: #2E7D32; text-align: justify;">
#         In our pursuit to comprehend the growth and distribution of wind energy capacity, particularly in Turkey and its neighboring regions, we confront key business questions. Our dataset serves as a compass, guiding us through the intricacies of regional wind energy capacity increments and market dynamics:
#     </p>
#     <ul style="font-family: 'Arial', sans-serif; font-size: 16px; color: #2E7D32; list-style: none;">
#         <li>🌬️ <strong>Regional Growth Dynamics:</strong> Understanding the rate of wind energy capacity development in Turkey compared to neighboring countries.</li>
#         <li>💡 <strong>Investment and Policy Influence:</strong> Identifying the impact of governmental policies and foreign investments on wind energy expansion.</li>
#         <li>📊 <strong>Market Positioning:</strong> Assessing Turkey's market positioning within the wind energy sector and its potential for future growth.</li>
#     </ul>
#     <p style="font-family: 'Arial', sans-serif; font-size: 16px; color: #2E7D32; text-align: justify;">
#         By dissecting the data, we aim to uncover actionable insights that drive strategic business decisions and foster sustainable growth in wind energy investment and infrastructure development.
#     </p>
# </div>

# %% [markdown]
# <div style="border: 10px solid #FFA500; border-radius: 15px; padding: 20px; box-shadow: 3px 3px 10px grey; background-color: #f4f4f4;">
#     <h2 style="font-size: 28px; font-weight: bold; color: #8B4513; text-align: center; border-bottom: 4px ridge #FFA500; font-family: 'Georgia'; padding: 10px;">Data Set Story</h2>
#     <p style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         Our dataset unfolds the story of wind energy's ascendance in Turkey and its neighboring regions, chronicling the journey from nascent stages to a formidable force in renewable energy. It captures the milestones and challenges, painting a picture of a region on the cusp of energy transformation. The dataset mirrors the commitment to a sustainable future, through the lens of wind energy capacity growth from 2000s onwards.
#     </p>
#     <ul style="font-size: 16px; font-family: 'Times New Roman'; padding: 10px;">
#         <li><strong>Entity:</strong> Represents the nations and regions, charting the course of wind energy capacity's impact in diverse geographical landscapes.</li>
#         <li><strong>Year:</strong> Denotes the chronological progression, providing a temporal backdrop for the expansion of wind energy.</li>
#         <li><strong>Wind Capacity (GW):</strong> Quantifies the energy potential harnessed, showcasing the evolution of wind power infrastructure and investment.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f8f9fa; padding: 20px; border-radius: 5px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h2 style="color: #343a40; text-align: center; font-size: 24px;">📜 Table of Contents</h2>
#     <ul style="list-style: none; padding-left: 0;">
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">1.</span> <a href="#GlobalWindEnergyCapacityOverYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Global Wind Energy Capacity Over Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">2.</span> <a href="#WindEnergyCapacityinTurkeyOverYears" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Wind Energy Capacity in Turkey Over Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">3.</span> <a href="#WindEnergyCapacityRankinginEuropein2021" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Wind Energy Capacity Ranking in Europe in 2021</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">4.</span> <a href="#RegionalWindCapacityOverTime" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Regional Wind Capacity Over Time</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">5.</span> <a href="#WindEnergyCapacityComparisonofTurkeyandNeighboringCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Wind Energy Capacity Comparison of Turkey and Neighboring Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">6.</span> <a href="#WindPowerCapacityDistributionofCertainCountriesintheLastYear" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Wind Power Capacity Distribution of Certain Countries in the Last Year</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">7.</span> <a href="#WindEnergyCapacityinTurkeyOverLast10Years" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Wind Energy Capacity in Turkey Over Last 10 Years</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">8.</span> <a href="#AnnualIncreaseinWindPowerCapacitybyRegion" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Annual Increase in Wind Power Capacity by Region</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">9.</span> <a href="#TotalWindPowerProductionofSpecifiedCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Total Wind Power Production of Specified Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">10.</span> <a href="#ComparisonofWindEnergyCapacityofTurkeyandNeighbouringCountries" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Comparison of Wind Energy Capacity of Turkey and Neighbouring Countries</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">11.</span> <a href="#GlobalWindEnergyCapacityMap" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Global Wind Energy Capacity Map</a>
#         </li>
#         <li style="background-color: rgba(255, 255, 255, 0.5); border: 1px solid #eaeaea; margin-bottom: 10px; border-radius: 5px; padding: 8px;">
#             <span style="font-weight: bold; font-size: 18px;">12.</span> <a href="#ConclusionFinalThoughts&Insights" style="text-decoration: none; color: #007BFF; font-weight: bold; font-size: 18px; display: inline-block; margin-left: 10px;">Conclusion: Final Thoughts & Insights</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Import Required Libraries</div></b>

# %%
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas as gpd
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker
import plotly.express as px
import plotly.graph_objects as go
import datetime
from sklearn.cluster import KMeans
from matplotlib.font_manager import FontProperties
from IPython.display import HTML as html_print
from termcolor import colored
from scipy import stats
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# <a id='Adjusting-Row-Column-Settings'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Adjusting Row Column Settings</div></b>

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Loading the Data Set</div></b>

# %%
df_9 = pd.read_csv("/kaggle/input/renewable-energy-world-wide-19652022/09 cumulative-installed-wind-energy-capacity-gigawatts.csv")

# %%
df_9.head()
# Out:
#    Entity Code  Year  Wind Capacity
# 0  Africa  NaN  1997          0.006
# 1  Africa  NaN  1998          0.010
# 2  Africa  NaN  1999          0.064
# 3  Africa  NaN  2000          0.139
# 4  Africa  NaN  2001          0.139

# %% [markdown]
# <a id='import-required-libraries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Exploratory Data Analysis</div></b>

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))

def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

check_df(df_9)
# Out:
# Shape
# (1540, 4)
# Types
# ...
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_3350e">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3350e_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_3350e_level0_col1" class="col_heading level0 col1" >Code</th>
#       <th id="T_3350e_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_3350e_level0_col3" class="col_heading level0 col3" >Wind Capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3350e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3350e_row0_col0" class="data row0 col0" >Africa</td>
#       <td id="T_3350e_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_3350e_row0_col2" class="data row0 col2" >1997</td>
#       <td id="T_3350e_row0_col3" class="data row0 col3" >0.006000</td>
#     </tr>
#     <tr>
# ...

# %%
df_9 = df_9.drop(columns=['Code'])

# %%
df_9.head()
# Out:
#    Entity  Year  Wind Capacity
# 0  Africa  1997          0.006
# 1  Africa  1998          0.010
# 2  Africa  1999          0.064
# 3  Africa  2000          0.139
# 4  Africa  2001          0.139

# %% [markdown]
# <a id='GlobalWindEnergyCapacityOverYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Wind Energy Capacity Over Years</div></b>

# %%
global_trend = df_9.groupby('Year')['Wind Capacity'].sum().reset_index()

frames = [go.Frame(
    data=[go.Scatter(x=global_trend['Year'][:k+1], y=global_trend['Wind Capacity'][:k+1], mode='lines+markers')],
    layout=go.Layout(title_text=f'Global Wind Energy Capacity Until {year}')
) for k, year in enumerate(global_trend['Year'])]

initial_frame = go.Frame(
    data=[go.Scatter(x=[global_trend['Year'].iloc[0]], y=[global_trend['Wind Capacity'].iloc[0]], mode='markers')],
    layout=go.Layout(title_text='Global Wind Energy Capacity (Initial Year)')
)
frames.insert(0, initial_frame)

fig = go.Figure(
    data=[go.Scatter(x=global_trend['Year'], y=global_trend['Wind Capacity'], mode='lines+markers')],
    layout=go.Layout(
        xaxis=dict(range=[global_trend['Year'].min(), global_trend['Year'].max()], autorange=False),
        yaxis=dict(range=[global_trend['Wind Capacity'].min(), global_trend['Wind Capacity'].max()], autorange=False),
        title="Global Wind Energy Capacity Over Years",
        updatemenus=[dict(
            type="buttons",
            buttons=[dict(label="Play",
                          method="animate",
                          args=[None])])]
    ),
    frames=frames
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This graph shows the steady increase of global wind energy capacity over time. The initial data point indicates the starting capacity, and the animation reveals annual growth. The 'Play' button allows users to view changes year by year. Overall, the graph demonstrates a clear trend towards more wind energy capacity globally. The interactive aspect helps in understanding the annual progress.
#   </p>
# </div>

# %% [markdown]
# <a id='WindEnergyCapacityinTurkeyOverYears'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Wind Energy Capacity in Turkey Over Years</div></b>

# %%
turkey_data = df_9[df_9['Entity'] == 'Turkey']

turkey_frames = [go.Frame(
    data=[go.Scatter(x=turkey_data['Year'][:k+1], y=turkey_data['Wind Capacity'][:k+1], mode='lines+markers')],
    layout=go.Layout(title_text=f'Wind Energy Capacity in Turkey Until {year}')
) for k, year in enumerate(turkey_data['Year'])]

turkey_initial_frame = go.Frame(
    data=[go.Scatter(x=[turkey_data['Year'].iloc[0]], y=[turkey_data['Wind Capacity'].iloc[0]], mode='markers')],
    layout=go.Layout(title_text='Wind Energy Capacity in Turkey (Initial Year)')
)
turkey_frames.insert(0, turkey_initial_frame)

turkey_fig = go.Figure(
    data=[go.Scatter(x=turkey_data['Year'], y=turkey_data['Wind Capacity'], mode='lines+markers')],
    layout=go.Layout(
        xaxis=dict(range=[turkey_data['Year'].min(), turkey_data['Year'].max()], autorange=False),
        yaxis=dict(range=[turkey_data['Wind Capacity'].min(), turkey_data['Wind Capacity'].max()], autorange=False),
        title="Wind Energy Capacity in Turkey Over Years",
        updatemenus=[dict(
            type="buttons",
            buttons=[dict(label="Play",
                          method="animate",
                          args=[None])])]
    ),
    frames=turkey_frames
)

turkey_fig.show()
# Out:
# <div>                            <div id="b52eba7c-4439-4542-864a-807b504d15da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b52eba7c-4439-4542-864a-807b504d15da")) {                    Plotly.newPlot(                        "b52eba7c-4439-4542-864a-807b504d15da",                        [{"mode":"lines+markers","x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.009,0.009,0.009,0.019,0.019,0.019,0.019,0.019,0.021,0.059,0.146,0.364,0.792,1.32,1.729,2.261,2.76,3.63,4.503,5.751,6.51615,7.005386000000001,7.591156,8.832356,10.606956],"type":"scatter"}],                        {"title":{"text":"Wind Energy Capacity in Turkey Over Years"},"updatemenus":[{"buttons":[{"a
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The graph depicts the growth of wind energy capacity in Turkey, starting from the earliest recorded year. Each frame adds a new year's data, showing incremental increases in capacity. The initial frame focuses on the starting point, providing context for the subsequent growth. The interactive 'Play' button allows for a step-by-step review of the yearly progress. This visualization effectively highlights Turkey's expanding investment in wind energy over the years.
#   </p>
# </div>

# %% [markdown]
# <a id='WindEnergyCapacityRankinginEuropein2021'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Wind Energy Capacity Ranking in Europe in 2021</div></b>

# %%
latest_year_data = df_9[df_9['Year'] == df_9['Year'].max()]

european_countries = ['Germany', 'Spain', 'United Kingdom', 'France', 'Italy', 'Sweden', 'Poland', 'Netherlands', 'Turkey']

europe_2021 = latest_year_data[latest_year_data['Entity'].isin(european_countries)].sort_values(by='Wind Capacity', ascending=False)

fig = px.bar(europe_2021, y='Entity', x='Wind Capacity', 
             title='Wind Energy Capacity Ranking in Europe in 2021',
             labels={'Entity': 'Country', 'Wind Capacity': 'Wind Capacity (GW)'},
             color='Wind Capacity',
             color_continuous_scale='Viridis',
             orientation='h')

fig.update_layout(
    xaxis_title='Wind Capacity (GW)',
    yaxis_title='Country',
    coloraxis_colorbar=dict(title='Wind Capacity (GW)'),
    plot_bgcolor='rgba(0,0,0,0)',  # Arka plan rengi
    template='plotly_white'
)

fig.show()
# Out:
# <div>                            <div id="fae1d94d-e79b-45b2-a161-f726ef8d8795" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fae1d94d-e79b-45b2-a161-f726ef8d8795")) {                    Plotly.newPlot(                        "fae1d94d-e79b-45b2-a161-f726ef8d8795",                        [{"alignmentgroup":"True","hovertemplate":"Wind Capacity (GW)=%{marker.color}\u003cbr\u003eCountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[63.76,27.49719,27.129990000000003,18.676002,12.08,11.275622,10.606956,7.801,6.9582500000000005],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[63.76,27.49719,27.129990000000003,18.676002,12.08,11
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This horizontal bar chart ranks European countries based on their wind energy capacity in 2021. The color gradient reflects the capacity magnitude, making high-capacity countries stand out. Germany leads, indicating its significant investment in wind energy. The chart effectively communicates the disparities in wind energy capacities across Europe. It underscores the varying degrees of commitment and resource allocation towards wind energy among European nations.
#   </p>
# </div>

# %% [markdown]
# <a id='RegionalWindCapacityOverTime'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Regional Wind Capacity Over Time</div></b>

# %%
regional_entities = ['Turkey', 'Germany', 'China', 'United States']

regional_yearly = df_9[df_9['Entity'].isin(regional_entities)].pivot(index='Year', columns='Entity', values='Wind Capacity')

fig = go.Figure()

for country in regional_entities:
    fig.add_trace(go.Scatter(x=regional_yearly.index, y=regional_yearly[country], mode='lines+markers', name=country,
                             line=dict(width=3), marker=dict(size=8)))

fig.update_layout(title={'text': "Regional Wind Capacity Over Time", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
                  xaxis_title='Year',
                  yaxis_title='Wind Capacity',
                  legend_title='Country/Region',
                  template='plotly_dark',  # Karanlık tema kullanma
                  margin=dict(l=20, r=20, t=60, b=20))

fig.show()
# Out:
# <div>                            <div id="56527861-23c4-4bff-89b1-25fe7ba25884" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56527861-23c4-4bff-89b1-25fe7ba25884")) {                    Plotly.newPlot(                        "56527861-23c4-4bff-89b1-25fe7ba25884",                        [{"line":{"width":3},"marker":{"size":8},"mode":"lines+markers","name":"Turkey","x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.009,0.009,0.009,0.019,0.019,0.019,0.019,0.019,0.021,0.059,0.146,0.364,0.792,1.32,1.729,2.261,2.76,3.63,4.503,5.751,6.51615,7.005386000000001,7.591156,8.832356,10.606956],"type":"scatter"},{"line":{"width":3},"marker":{"size":8},"mode":"lines+markers"
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The line graph compares wind energy capacities across Turkey, Germany, China, and the United States over time. Each country is represented by a distinct line, with markers at each data point for clarity. The use of a dark theme enhances visibility and focuses attention on the data lines. The graph demonstrates the varying growth rates in wind energy capacity among these regions. It highlights the progressive increase in wind capacity, underscoring the global move towards renewable energy sources.
#   </p>
# </div>

# %% [markdown]
# <a id='WindEnergyCapacityComparisonofTurkeyandNeighboringCountrie'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Wind Energy Capacity Comparison of Turkey and Neighboring Countries</div></b>

# %%
neighboring_countries = ['Turkey', 'Greece', 'Bulgaria', 'Georgia', 'Armenia', 'Iran', 'Iraq', 'Syria']

neighbors_data = df_9[df_9['Entity'].isin(neighboring_countries)]

fig = px.line(neighbors_data, x='Year', y='Wind Capacity', color='Entity', markers=True,
              title='Wind Energy Capacity Comparison of Turkey and Neighboring Countries',
              labels={'Wind Capacity': 'Wind Capacity (GW)', 'Year': 'Year', 'Entity': 'Country'})

fig.update_layout(
    xaxis=dict(showgrid=True, gridwidth=0.5, gridcolor='LightPink'),
    yaxis=dict(showgrid=True, gridwidth=0.5, gridcolor='LightPink'),
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(title='Country', orientation="h", y=1, yanchor="bottom", x=0.5, xanchor="center"),
    font=dict(family="Arial, sans-serif", size=12, color="RebeccaPurple")
)

fig.show()
# Out:
# <div>                            <div id="7f3876eb-1dea-42c1-8483-8f7e992b1cf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f3876eb-1dea-42c1-8483-8f7e992b1cf4")) {                    Plotly.newPlot(                        "7f3876eb-1dea-42c1-8483-8f7e992b1cf4",                        [{"hovertemplate":"Country=Bulgaria\u003cbr\u003eYear=%{x}\u003cbr\u003eWind Capacity (GW)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Bulgaria","orientation":"v","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[0.0,0.0,0.
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This line graph provides a comparative view of wind energy capacities across Turkey and its neighboring countries over several years. Distinct lines for each country, marked with data points, facilitate a clear comparison. The soft grid and background ensure data lines are prominently displayed against a non-distracting backdrop. The horizontal legend aids in identifying each country's line without cluttering the graph. This visualization effectively showcases the regional dynamics in wind energy capacity.
#   </p>
# </div>

# %% [markdown]
# <a id='WindPowerCapacityDistributionofCertainCountriesintheLastYear'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Wind Power Capacity Distribution of Certain Countries in the Last Year</div></b>

# %%
specific_entities = ['Turkey', 'United States', 'Canada', 'China', 'Germany', 'United Kingdom', 'France']
filtered_data = latest_year_data[latest_year_data['Entity'].isin(specific_entities)]

plt.figure(figsize=(10, 7))
wedges, texts, autotexts = plt.pie(filtered_data['Wind Capacity'], startangle=140, colors=plt.cm.tab20.colors, autopct='%1.1f%%', pctdistance=0.85)

plt.legend(wedges, filtered_data['Entity'], title="Countries", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.title('Wind Power Capacity Distribution of Certain Countries in the Last Year', fontsize=12)
plt.axis('equal')

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The pie chart illustrates the distribution of wind power capacity among selected countries for the most recent year available. Each slice represents a country's share, with percentages indicating the proportion of global wind capacity. The chart employs a diverse color palette for clear differentiation between countries. The 'donut' style, achieved by adding a central white circle, enhances readability and visual appeal. The external legend facilitates identification of each country without overcrowding the chart itself.
#   </p>
# </div>

# %% [markdown]
# <a id='WindEnergyCapacityinTurkeyOverLast10Years'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Wind Energy Capacity in Turkey Over Last 10 Years</div></b>

# %%
recent_10_years_turkey = df_9[(df_9['Entity'] == 'Turkey') & (df_9['Year'] >= df_9['Year'].max() - 10)]

recent_10_years_turkey_frames = [go.Frame(
    data=[go.Scatter(x=recent_10_years_turkey['Year'][:k+1], y=recent_10_years_turkey['Wind Capacity'][:k+1], mode='lines+markers')],
    layout=go.Layout(title_text=f'Wind Energy Capacity in Turkey Until {year}')
) for k, year in enumerate(recent_10_years_turkey['Year'])]

recent_10_years_turkey_fig_updated = go.Figure(
    data=[go.Scatter(x=recent_10_years_turkey['Year'], y=recent_10_years_turkey['Wind Capacity'], mode='lines+markers')],
    layout=go.Layout(
        xaxis=dict(title='Year', range=[recent_10_years_turkey['Year'].min(), recent_10_years_turkey['Year'].max()], autorange=False),
        yaxis=dict(title='Wind Capacity (GW)', range=[recent_10_years_turkey['Wind Capacity'].min(), recent_10_years_turkey['Wind Capacity'].max()], autorange=False),
        title="Wind Energy Capacity in Turkey Over Last 10 Years",
        updatemenus=[dict(type="buttons", buttons=[dict(label="Play", method="animate", args=[None])])]
    ),
    frames=recent_10_years_turkey_frames
)

recent_10_years_turkey_fig_updated
# Out:
# <div>                            <div id="bba30f6c-9932-4e60-bf88-15661b04b290" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bba30f6c-9932-4e60-bf88-15661b04b290")) {                    Plotly.newPlot(                        "bba30f6c-9932-4e60-bf88-15661b04b290",                        [{"mode":"lines+markers","x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.729,2.261,2.76,3.63,4.503,5.751,6.51615,7.005386000000001,7.591156,8.832356,10.606956],"type":"scatter"}],                        {"title":{"text":"Wind Energy Capacity in Turkey Over Last 10 Years"},"updatemenus":[{"buttons":[{"args":[null],"label":"Play","method":"animate"}],"type":"buttons"}],"xaxis":{"autorange":false,"range":[2011,2021],"title":{"text":"Year"}},"yaxis
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This animated graph tracks the progression of wind energy capacity in Turkey over the past decade, highlighting yearly advancements through an interactive timeline. The inclusion of markers at each data point provides a clear indication of annual capacity levels. The animation feature allows for an engaging exploration of Turkey's wind energy growth, emphasizing the significant strides made in increasing capacity. The graph's layout, with its clear axis titles and range settings, ensures the data's trends are easily interpretable. Overall, this visualization underscores Turkey's commitment to enhancing its wind energy infrastructure.
#   </p>
# </div>

# %% [markdown]
# <a id='AnnualIncreaseinWindPowerCapacitybyRegion'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Annual Increase in Wind Power Capacity by Region</div></b>

# %%
yearly_increase = df_9.groupby(['Year', 'Entity'])['Wind Capacity'].sum().unstack().fillna(0).diff().fillna(0)

top_entities = yearly_increase.sum(axis=0).sort_values(ascending=False).head(5).index

filtered_yearly_increase = yearly_increase[top_entities]

filtered_yearly_increase.plot(kind='bar', figsize=(15, 8), width=0.7)
plt.title('Annual Increase in Wind Power Capacity by Region')
plt.xlabel('Year')
plt.ylabel('Increase in Wind Capacity (GW)')
plt.xticks(rotation=90)
plt.legend(title='Region')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This bar chart showcases the annual increase in wind power capacity for the top five regions with the most significant growth. Each bar represents the year-on-year capacity increment within these regions, allowing for an easy comparison of growth rates. The choice of a bar chart effectively communicates the fluctuations in annual capacity increases. The inclusion of a grid and clearly labeled axes aids in data interpretation. The chart underscores the dynamic nature of wind power expansion in these leading regions.
#   </p>
# </div>

# %% [markdown]
# <a id='TotalWindPowerProductionofSpecifiedCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Total Wind Power Production of Specified Countries</div></b>

# %%
specified_countries = ['Austria', 'Belgium', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Italy', 
                      'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom']

specified_countries_wind_data = df_9[df_9['Entity'].isin(specified_countries)]

total_wind_production_specified_countries = specified_countries_wind_data.groupby('Entity')['Wind Capacity'].sum().sort_values(ascending=False)

plt.figure(figsize=(20, 8))
bars = plt.bar(total_wind_production_specified_countries.index, total_wind_production_specified_countries.values, color='grey')
plt.title('Total Wind Power Production of Specified Countries', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12, fontweight='bold')
plt.ylabel('Electricity from Wind (TWh)', fontsize=12, fontweight='bold')
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)

for bar in bars:
    if bar.get_x() + bar.get_width() / 2 == total_wind_production_specified_countries.index.get_loc("Turkey"):
        bar.set_color('blue')
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom', fontsize=10)

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The bar chart ranks selected European countries by their total wind power production, highlighting Turkey with a distinct blue bar. The visualization allows for easy comparison between countries, showcasing leaders in wind energy. Numeric labels atop each bar provide exact production values, enhancing the chart's informativeness. The uniform grey color scheme, except for Turkey, focuses attention on Turkey's position in the ranking. This chart effectively communicates the disparity in wind energy production across these nations.
#   </p>
# </div>

# %% [markdown]
# <a id='ComparisonofWindEnergyCapacityofTurkeyandNeighbouringCountries'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Comparison of Wind Energy Capacity of Turkey and Neighbouring Countries</div></b>

# %%
turkey_neighbors = ['Greece', 'Bulgaria', 'Georgia', 'Armenia', 'Iran', 'Azerbaijan', 'Iraq', 'Syria']

neighbors_wind_capacity = latest_year_data[latest_year_data['Entity'].isin(turkey_neighbors + ['Turkey'])].sort_values(by='Wind Capacity', ascending=False)

plt.figure(figsize=(10, 7))
plt.pie(neighbors_wind_capacity['Wind Capacity'], labels=neighbors_wind_capacity['Entity'], autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20c(np.linspace(0, 1, len(neighbors_wind_capacity))))
plt.title('Comparison of Wind Energy Capacity of Turkey and Neighbouring Countries')
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> This pie chart visualizes the distribution of wind energy capacity between Turkey and its neighboring countries. Each slice represents a country's share of the total capacity, with Turkey likely being a significant portion. The chart uses a color gradient to differentiate between countries, making it visually appealing and easy to interpret. The use of percentages allows for a quick understanding of each country's contribution. This visualization effectively highlights Turkey's role in regional wind energy production.
#   </p>
# </div>

# %% [markdown]
# <a id='GlobalWindEnergyCapacityMap'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Global Wind Energy Capacity Map</div></b>

# %%
fig = px.choropleth(
    df_9,
    locations="Entity",
    locationmode="country names",
    color="Wind Capacity", 
    animation_frame="Year",
    color_continuous_scale="YlGnBu", 
    range_color=(0, df_9['Wind Capacity'].max()) 
)

fig.update_geos(projection_type="natural earth")

fig.update_layout(
    title="Global Wind Energy Capacity Map", 
    coloraxis_colorbar={"title": "Wind Energy Capacity (GW)"}
)

fig.show()
# Out:
# <div>                            <div id="3c146f3b-6d39-441d-8c2b-35e668c1a37f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c146f3b-6d39-441d-8c2b-35e668c1a37f")) {                    Plotly.newPlot(                        "3c146f3b-6d39-441d-8c2b-35e668c1a37f",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Year=1997\u003cbr\u003eEntity=%{location}\u003cbr\u003eWind Capacity=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Africa","Africa (BP)","Argentina","Asia","Asia Pacific (BP)","Australia","Austria","Belgium","Brazil","Bulgaria","Canada","Chile","China","Costa Rica","Denmark","Egypt","Europe","Europe (BP)","Finland","France","Germany","Greece","High-income countries"
# ...

# %% [markdown]
# <div style="background-color: #f9f9f9; border-left: 5px solid #3182bd; padding: 10px 15px; margin: 10px 0;">
#   <p style="font-family: Arial, sans-serif; font-size: 14px; color: #333;">
#     <strong>Graph Analysis:</strong> The choropleth map dynamically illustrates the evolution of global wind energy capacity across various countries, year by year. The color gradient, ranging from lighter to darker shades, quantifies the wind capacity, making high-capacity regions easily identifiable. The animation feature allows for a temporal exploration of how wind energy has expanded worldwide. The 'natural earth' projection ensures a realistic representation of geographical features. This map not only showcases current wind energy capacities but also the growth trend over the years, reflecting increased adoption of wind energy globally.
#   </p>
# </div>

# %% [markdown]
# <a id='ConclusionFinalThoughts&Insights'></a>
# # <b><div style='padding:15px;background-color:#004080;color:white;border-radius:15px;font-size:100%;text-align: center'>Conclusion Final Thoughts & Insights</div></b>

# %% [markdown]
# <div style="background-color: #fafafa; border: 2px solid #6A5ACD; padding: 15px; margin-top: 10px; border-radius: 10px;">
#     <h2 style="color: #6A5ACD; font-family: 'Lucida Sans Unicode', sans-serif; font-size: 18px; font-weight: bold; text-align: center;">Conclusion: Embracing Wind Energy's Potential</h2>
#     <p style="font-family: 'Lucida Sans Unicode', sans-serif; font-size: 14px; color: #333; text-align: justify;">
#         Our analytical journey through the wind energy capacity data has illuminated the growing role of wind power as an integral part of the global push towards renewable energy. The insights gained from comparing Turkey's progress with its neighbors, and examining the wind capacity in various European countries, highlight a broader trend of increasing reliance on cleaner energy sources.
#     </p>
#     <p style="font-family: 'Lucida Sans Unicode', sans-serif; font-size: 14px; color: #333; text-align: justify;">
#         The dynamic visuals and data-driven narratives have showcased not only the current state of wind energy but also the promising trajectory it holds for the future. The continuous growth in wind capacity underscores the viability and necessity of wind energy in achieving sustainable development goals. This analysis serves as a call to action, urging nations and stakeholders to further invest in wind energy, leveraging its potential to foster a more sustainable and resilient energy landscape.
#     </p>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'> :) |</span></b> <b>Just Click For More Fun</b></div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/vedatgul/code" class="link-card">
#   <span class="link-icon">📈</span>
#   <span class="link-text">Vedat GUL's Notebook</span>
# </a>
# <a href="https://www.kaggle.com/sinanimek/code" class="link-card">
#   <span class="link-icon">📉</span>
#   <span class="link-text">Sinan SIMSEK's Notebook</span>
# </a>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #FFFFFF; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/10-harnessing-the-wind/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>
